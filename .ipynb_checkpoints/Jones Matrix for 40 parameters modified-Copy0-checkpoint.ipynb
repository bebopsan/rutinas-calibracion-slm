# %% [markdown]
# # Scripts para la construcción de la matriz de Jones usando las medidas experimentales

# %% [markdown]
# Importación de librerias y carga de archivos.

# %%
from sympy import symbols, Matrix
from numpy import loadtxt, zeros, matrix, exp, pi, sqrt, sign, cos, sin
from scipy.optimize import minimize
import matplotlib.gridspec as gridspec
from pylab import *
# %pylab inline

I_exp = {}
I = {}
for i in range(70):
   # image = "Imagen{0}_amp".format(i)
    image = "In-fourier{0}_amp".format(i)
    I_exp[i+1] = loadtxt(image)    
    I[i+1] = zeros(52)
    
#I_exp[41] =  loadtxt("In21_amp")
#I[41] = zeros(52)
#I_exp[42] =  loadtxt("In22_amp")
#I[42] = zeros(52)
I_exp_2 = I_exp
# Out:
# C:\Users\franjas\Anaconda\envs\py3k\lib\site-packages\matplotlib\mathtext.py:46: UserWarning: Due to a bug in pyparsing <= 2.0.0 on Python 3.x, packrat parsing has been disabled.  Mathtext rendering will be much slower as a result.  Install pyparsing 2.0.0 or later to improve performance.
#   warn("Due to a bug in pyparsing <= 2.0.0 on Python 3.x, packrat parsing "
# WARNING:
# Populating the interactive namespace from numpy and matplotlib
# pylab import has clobbered these variables: ['random', 'info', 'power', 'draw_if_interactive', 'linalg', 'fft']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# ## Normalización

# %% [markdown]
# En este punto suceden dos cosas, primero realizo una normalización por pares.
# Asumiendo que cada medida esta antecedida por su estado ortogonal, lo que hago es:
# $$I_i = \frac{I_i^{exp}}{I_i^{exp}+I_{i+1}^{exp}}$$

# %%
# Averaging of intensities
for i in range(1,71,2):
    for g in range(I_exp[i].shape[0]):
        I[i][g] = I_exp[i][g,1]/(I_exp[i][g,1]+I_exp[i+1][g,1])
        I[i+1][g] = I_exp[i+1][g,1]/(I_exp[i][g,1]+I_exp[i+1][g,1])

# %% [markdown]
# Graficación de las curvas de indensidad normalizadas

# %% [markdown]
# Estas son las curvas equivalentes a las curvas de intensidad que se usan para caracterizar el modulador en el artículo de Moreno.

# %%
fig = figure()
for i in range(1,71):
    plot(I[i],label='I{0}'.format(i))
#plot(I[5]+I[6],label='I{0}'.format(i))

show()

# %% [markdown]
# Demonstration that coniguous sets of amplitude measures are complementary. Pairs of complementary measures add up to zero.

# %%
for i in range(1,71,2):
    plot(I[i]+I[i+1],label='I{0}'.format(i))
    
show()

# %%
#fig = figure()
#plot(I[1],label='I1')
#plot(I[2],label='I2')
#plot(I[4],label='I3')
#plot(I[42],label='I4')
#plot(I[21],label='I5')
#plot(I[22],label='I6')
#plot(I[5],label='I7')
#plot(I[6],label='I7p')
#legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#display(fig)

# %% [markdown]
# ## Definición de X, Y, Z y W

# %% [markdown]
# Siguiendo las fórmulas que se exponen en el artículo de Moreno y Velazques
# encuentro los valores de X, Y, Z, y W, y sus signos.

# %%
X = zeros(52)
Y = zeros(52)
Z = zeros(52)
W = zeros(52)
#for i in range(3,43,2):
#    delta = I[i][0]-I[i+1][0]
#   I[i] = I[i]- delta/2
#    I[i+1] = I[i+1] + delta/2
#for g in range(I[1].shape[0]):
#    X[g] = sqrt( I[1][g]/(1+( (I[5][g]-I[22][g])/(I[4][g]-I[42][g]) )**2) )
#    Y[g] = sqrt( I[1][g]/(1+( (I[4][g]-I[42][g])/(I[5][g]-I[22][g]) )**2) )
#    Z[g] = sqrt( I[2][g]/(1+( (I[4][g]-I[42][g])/(I[21][g]-I[5][g]) )**2) )
#    W[g] = sqrt( I[2][g]/(1+( (I[21][g]-I[5][g])/(I[4][g]-I[42][g]) )**2) )
    
#    sign_Z = sign(I[21][g]-I[5][g])/sign(X[g])
#    if sign(Z[g]) != sign_Z:
#        Z[g] = Z[g]*-1
#    sign_W = sign(I[4][g]-I[42][g])/sign(X[g])
#    if sign(W[g]) != sign_W:
#       W[g] = W[g]*-1
#    sign_Y = sign(I[5][g]-I[22][g])/sign(X[g])
#    if sign(Z[g]) != sign_Y:
#        Y[g] = Y[g]*-1

# %% [markdown]
# Graficas de X, Y, Z y W:

# %%
## figure()
## plot(X,label='X,76,34')
## plot(Y,label='Y,34,76')
## plot(Z,label='Z, 34,57')
## plot(W,label='W, 57,34')
## grid()
## legend()

# %% [markdown]
# ## Matriz de Jones del modulador

# %% [markdown]
# Definición de Brakets siguiendo la formulación de vectores de Jones.

# %%
I_exp = I
def intensity(bra,ket):
    In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
    Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
    return In, Out
brakets = {1:intensity([ 0,   0],     [0,0]),\
           2:intensity([ pi/2,0],     [0,0]),\
           3:intensity([ pi/4,pi/2],  [0,0]),\
           4:intensity([ pi/4,-pi/2],  [0,0]),\
           5:intensity([ pi/4, 0],    [0,0]),\
           6:intensity([-pi/4, 0],    [0,0]),\
           7:intensity([ 3*pi/8, pi/2],  [0,0]),\
           8:intensity([pi/8,-pi/2],[0,0]),\
           9:intensity([ pi/8, pi/4],   [0,0]),\
           10:intensity([-pi/8, 3*pi/4],[0,0]),\
           11:intensity([ 0,   0],     [pi/2,0]),\
           12:intensity([ pi/2,0],     [pi/2,0]),\
           13:intensity([ pi/4,pi/2],  [pi/2,0]),\
           14:intensity([ pi/4,-pi/2],  [pi/2,0]),\
           15:intensity([ pi/4, 0],    [pi/2,0]),\
           16:intensity([-pi/4, 0],    [pi/2,0]),\
           17:intensity([ 3*pi/8, pi/2],  [pi/2,0]),\
           18:intensity([ pi/8, -pi/2],[pi/2,0]),\
           19:intensity([ pi/8, pi/4],   [pi/2,0]),\
           20:intensity([-pi/8, 3*pi/4],   [pi/2,0]),\
           21:intensity([ 0,   0],     [pi/4,0]),\
           22:intensity([ pi/2,0],     [pi/4,0]),\
           23:intensity([ pi/4,pi/2],  [pi/4,0]),\
           24:intensity([ pi/4,-pi/2],  [pi/4,0]),\
           25:intensity([ pi/4, 0],    [pi/4,0]),\
           26:intensity([-pi/4, 0],    [pi/4,0]),\
           27:intensity([3*pi/8, pi/2],  [pi/4,0]),\
           28:intensity([pi/8, -pi/2],[pi/4,0]),\
           29:intensity([pi/8, pi/4],   [pi/4,0]),\
           30:intensity([-pi/8, 3*pi/4],[pi/4,0]),\
           31:intensity([ 0,   0],     [-pi/4,0]),\
           32:intensity([ pi/2,0],     [-pi/4,0]),\
           33:intensity([ pi/4,pi/2],  [-pi/4,0]),\
           34:intensity([ pi/4,-pi/2],  [-pi/4,0]),\
           35:intensity([ pi/4, 0],    [-pi/4,0]),\
           36:intensity([-pi/4, 0],    [-pi/4,0]),\
           37:intensity([3*pi/8, pi/2],  [-pi/4,0]),\
           38:intensity([pi/8, -pi/2],[-pi/4,0]),\
           39:intensity([pi/8, pi/4],   [-pi/4,0]),\
           40:intensity([-pi/8, 3*pi/4],[-pi/4,0]),\
	       41:intensity([ 0,   0],      [pi/4,pi/2]),\
           42:intensity([ pi/2,0],      [pi/4,pi/2]),\
           43:intensity([ pi/4,pi/2],   [pi/4,pi/2]),\
           44:intensity([ pi/4,-pi/2],  [pi/4,pi/2]),\
           45:intensity([ pi/4, 0],     [pi/4,pi/2]),\
           46:intensity([-pi/4, 0],     [pi/4,pi/2]),\
           47:intensity([3*pi/8, pi/2], [pi/4,pi/2]),\
           48:intensity([pi/8, -pi/2],  [pi/4,pi/2]),\
           49:intensity([pi/8, pi/4],   [pi/4,pi/2]),\
           50:intensity([-pi/8, 3*pi/4],[pi/4,pi/2]),\
	       51:intensity([ 0,   0],      [3*pi/8,pi/2]),\
           52:intensity([ pi/2,0],      [3*pi/8,pi/2]),\
           53:intensity([ pi/4,pi/2],   [3*pi/8,pi/2]),\
           54:intensity([ pi/4,-pi/2],  [3*pi/8,pi/2]),\
           55:intensity([ pi/4, 0],     [3*pi/8,pi/2]),\
           56:intensity([-pi/4, 0],     [3*pi/8,pi/2]),\
           57:intensity([3*pi/8, pi/2], [3*pi/8,pi/2]),\
           58:intensity([pi/8, -pi/2],  [3*pi/8,pi/2]),\
           59:intensity([pi/8, pi/4],   [3*pi/8,pi/2]),\
           60:intensity([-pi/8, 3*pi/4],[3*pi/8,pi/2]),\
           61:intensity([ 0,   0],      [pi/8,0]),\
           62:intensity([ pi/2,0],      [pi/8,0]),\
           63:intensity([ pi/4,pi/2],   [pi/8,0]),\
           64:intensity([ pi/4,-pi/2],  [pi/8,0]),\
           65:intensity([ pi/4, 0],     [pi/8,0]),\
           66:intensity([-pi/4, 0],     [pi/8,0]),\
           67:intensity([3*pi/8, pi/2], [pi/8,0]),\
           68:intensity([pi/8, -pi/2],  [pi/8,0]),\
           69:intensity([pi/8, pi/4],   [pi/8,0]),\
           70:intensity([-pi/8, 3*pi/4],[pi/8,0])}

# %% [markdown]
# Definición de una función a minimizar. Esta función calcula las diferencias cuadradas
# entre las medidas experimentales y las intensidades resultantes de operar con los
# vectores de Jones:

# %%
def min_sq(x0,I_exp,g,alpha,psi,brakets):
    """ Calculates squared differences for a minimization procedure.

    Given the experimental meassures of intensity and arbitrary values for 
    the parameters of an SLM Jones Matrix, this function gives a value to
    minimize. That value tells how close is the estimation of alpha, beta, psi, delta 
    to the value that correctly models the SLM.

    :param alpha,beta,psi,delta: Are a guess of real scalars that conform physical parameters the SLM.
    :param I_exp: Is a dictionary contanining intensities for every polarization state.
    :param g: Is the gray level of the SLM for which we are solving.
    """
    [beta, delta] = x0
    
    R = matrix([[ cos(alpha), sin(alpha)],\
                [-sin(alpha), cos(alpha)]])
    R_global = matrix([[ cos(psi), sin(psi)],\
                       [-sin(psi), cos(psi)]])
    
    gamma = sqrt(alpha**2 + beta**2)
    x = cos(gamma)
    y = beta*sin(gamma)/gamma
    z = alpha*sin(gamma)/gamma
    
    M_xyz = matrix([[ x - y*1j, z     ],\
                    [-z       , x+y*1j]])
    
    M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
    
    W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                       [      0        , exp(1j*delta)]])
    M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
    
    M = R_global.transpose()*M_LCDp*R_global
    
    min_sum = 0
    I_sim = {}
    for i in range(1,71):
        #if i%2 !=0:
	#if i in [1,2,5,6,11,12,15,16,21,22,25,26,31,32,36,35]:
        #if i in [1,2,3,4,5,6,11,12,15,16,21,22,25,26,31,33,35,36]:
        if i not in []:
        #if i not in [9,10,19,20,29,30,39,40,49,50,59,60,69,70]:
            In, Out = brakets[i]
            I_sim[i] = (In.H*M.H*Out * Out.H*M*In)
            min_sum += ((I_sim[i]-I_exp[i][g])**2)[0,0].real
            #min_sum += (sqrt(abs(I_sim[i]**2-I_exp[i][g]**2)))[0,0].realqq
    
    return min_sum

# %% [markdown]
# Si probamos con unos valores iniciales cualquiera debe devolver un número escalar:

# %%
min_sq([2.6,0],I_exp,0,-pi/2,pi/4, brakets)
# Out:
# 15.478685699835451

# %% [markdown]
# Minimización con restricciónes de caja. El método que mejor hace la minimización es el SLSQP:

# %%
M = {}
bnds = ((-pi/4, 2*pi), (0, 2*pi))
cons = ({'type': 'eq', 'fun': lambda x:  x[0]**2+x[1]**2+x[2]**2+x[3]**2 - 1})
from scipy.optimize import fmin_l_bfgs_b
beta,delta = pi, 0.5
Beta, Delta = [],[]
alpha,psi = -1.63400317439, -0.627396281551
for g in range(51,-1,-1):   
    #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
    #res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'Nelder-Mead')
    res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP',bounds =bnds)
    #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')        
    #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
    #res = fmin_l_bfgs_b(min_sq,[ 2.6,  0],fprime=None,approx_grad=1, args = (I_exp,g,alpha,psi,brakets),pgtol=1e-05)
    
    #beta,delta = res[0]
    beta,delta = res.x
    if delta > pi/4:
            delta = 0
    Beta.append(beta)
    Delta.append(delta)
    R = matrix([[ cos(alpha), sin(alpha)],\
                [-sin(alpha), cos(alpha)]])
    R_global = matrix([[ cos(psi), sin(psi)],\
                       [-sin(psi), cos(psi)]])
    
    gamma = sqrt(alpha**2 + beta**2)
    x = cos(gamma)
    y = beta*sin(gamma)/gamma
    z = alpha*sin(gamma)/gamma
    M_xyz = matrix([[ x - y*1j, z     ],\
                    [-z       , x+y*1j]])
    
    M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
    
    W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                       [      0        , exp(1j*delta)]])
    M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
    
    M[g] = R_global.transpose()*M_LCDp*R_global
    print(res.x)
# Out:
# [  2.35812935e+00   5.64325187e-13]
# [  2.28877792e+00  -1.53328427e-15]
# [  2.21319712e+00  -5.45730802e-16]
# [  2.13717659e+00  -9.05304930e-17]
# [ 2.04293773  0.00696686]
# [ 1.92598342  0.02694819]
# [ 1.80958242  0.04503423]
# [ 1.69487862  0.06426767]
# [ 1.58225748  0.08052435]
# [ 1.47308134  0.09619293]
# [ 1.3547471   0.11541888]
# [ 1.25492655  0.12553407]
# [ 1.14119533  0.14194649]
# [ 1.03309814  0.1575701 ]
# [ 0.93642947  0.16685136]
# [ 0.83965824  0.17384286]
# [ 0.73986273  0.18239994]
# [ 0.64731766  0.18921742]
# [ 0.56227384  0.19085331]
# [ 0.47994556  0.19596594]
# [ 0.40268063  0.18782728]
# [ 0.33733008  0.17654889]
# [ 0.27354651  0.1651205 ]
# [ 0.21436764  0.14138466]
# [ 0.1566893   0.10958418]
# [ 0.10074716  0.0345287 ]
# [  6.03088932e-02  -3.46944695e-17]
# [  2.99271640e-02  -2.80883207e-17]
# [  5.54962164e-03  -2.22261445e-18]
# [ -1.66908495e-04   5.31231740e-01]
# [ -3.13104242e-05   7.15877846e-01]
# [ -2.03175376e-05   8.20591155e-01]
# [ -1.19735398e-04   8.77362933e-01]
# [-0.04575794  0.6934188 ]
# [-0.08020027  0.60271297]
# [-0.10677452  0.5536669 ]
# [-0.12680967  0.52066946]
# [-0.14797432  0.48973603]
# [-0.16336222  0.47632292]
# [-0.1777972   0.46365625]
# [-0.19197501  0.4519935 ]
# [-0.20485926  0.44184965]
# [-0.21613999  0.43339663]
# [-0.22657522  0.42663828]
# [-0.23713844  0.41976594]
# [-0.24602198  0.41477816]
# [-0.25407419  0.41042639]
# [-0.26198661  0.40658709]
# [-0.2694401   0.40267093]
# [-0.27572719  0.40029665]
# [-0.28221224  0.39519113]
# [-0.28772042  0.39383577]

# %% [markdown]
# Figura que compara las intensidades normalizadas experimentales en verde con las intensidades
# normalizadas producidas por los vectores de Jones definidos antes entrando y saliendo de la matriz
# que resulta de la caracterización.

# %%
#%pylab inline 

fig = figure()
gs1 = gridspec.GridSpec(8, 6)
axes = []
for i in range(8):
    for j in range(6):
        #if i+j!=6:
        axes.append(fig.add_subplot(gs1[i,j]))
        
for i in range(1,40,2):
    In1, Out1 = brakets[i]
    In2, Out2 = brakets[i+1]
    
    I_test1 = zeros(52)
    I_test2 = zeros(52)
    
    for g in range(52):
        I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        
    n = '8'+str(g)
    axes[i-1].plot(I_test1, label = 'It')
    axes[i-1].plot(I_exp[i], label = 'Ie')
    axes[i-1].set_title('$I_{'+str(i)+'}$')
    axes[i-1].set_ylim(0, 1)
    axes[i].set_ylim(0, 1)
    axes[i].plot(I_test2, label = 'It')
    axes[i].plot(I_exp[i+1], label = 'Ie')
    axes[i].set_title('$I_{'+str(i+1)+'}$')
show()

# %%
#%pylab inline 

fig = figure()
gs1 = gridspec.GridSpec(8, 6)
axes = []
for i in range(8):
    for j in range(6):
        #if i+j!=6:
        axes.append(fig.add_subplot(gs1[i,j]))
        
for i in range(41,71,2):
    In1, Out1 = brakets[i]
    In2, Out2 = brakets[i+1]
    
    I_test1 = zeros(52)
    I_test2 = zeros(52)
    
    for g in range(52):
        I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        
    n = '8'+str(g)
    axes[i-1-41].plot(I_test1, label = 'It')
    axes[i-1-41].plot(I_exp[i], label = 'Ie')
    axes[i-1-41].set_title('$I_{'+str(i)+'}$')
    axes[i-1-41].set_ylim(0, 1)
    axes[i-41].set_ylim(0, 1)
    axes[i-41].plot(I_test2, label = 'It')
    axes[i-41].plot(I_exp[i+1], label = 'Ie')
    axes[i-41].set_title('$I_{'+str(i+1)+'}$')
show()

# %%
def min_all(x0,I_exp,g,brakets):
    min_of_functions = 0
    beta,delta = pi, 0
    M = {}
    bnds = ((0, 2*pi), (0, pi/4))   
    alpha,psi = x0
    for g in range(51,-1,-1):   
        #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
        res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP', bounds = bnds)
        #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')        
        #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
        #res = fmin_l_bfgs_b(min_sq,[ 2.6,  0],fprime=None,approx_grad=1, args = (I_exp,g,alpha,psi,brakets),pgtol=1e-05)
        
        #alpha,beta,psi,delta = res[0]
        beta,delta = res.x
        
        R = matrix([[ cos(alpha), sin(alpha)],\
                    [-sin(alpha), cos(alpha)]])
        R_global = matrix([[ cos(psi), sin(psi)],\
                           [-sin(psi), cos(psi)]])
        
        gamma = sqrt(alpha**2 + beta**2)
        x = cos(gamma)
        y = beta*sin(gamma)/gamma
        z = alpha*sin(gamma)/gamma
        M_xyz = matrix([[ x - y*1j, z     ],\
                        [-z       , x+y*1j]])
        
        M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
        
        W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                           [      0        , exp(1j*delta)]])
        M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
        
        M[g] = R_global.transpose()*M_LCDp*R_global
        
        min_of_functions += res.fun
    print(alpha,psi)    
    print(min_of_functions)
    return min_of_functions

# %%
#result = minimize(min_all,[-pi/2,-pi/4], args = (I_exp,g,brakets),method = 'Nelder-Mead')

# %% [markdown]
# Extracción de los parámetros X, Y, Z, y W obtenidos por minimización:

# %%
for g in range(52):
     X[g] = M[g][0,0].real
     Y[g] = -M[g][0,0].imag
     Z[g] = M[g][0,1].real
     W[g] = -M[g][0,1].imag

# %% [markdown]
# Gráfica de X, Y, Z, y W

# %% [markdown]
# Figura que compara las intensidades experimentales en verde con las intensidades
# producidas por los vectores de Jones definidos antes entrando y saliendo de la matriz
# que resulta de la caracterización.

# %%
f = figure()
ax = f.gca()
plot(X,label='X,76,34')
plot(Y,label='Y,34,76')
plot(Z,label='Z, 34,57')
plot(W,label='W, 57,34')
grid()
# Shink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
legend(bbox_to_anchor=(1.01, 1), loc=2)
show()

# %%
bet = figure()
ax = f.gca()
plot(Beta, label = 'beta')
plot(Delta, label = 'delta')
grid()
show()

# %% [raw]
# fig = figure()
# gs1 = gridspec.GridSpec(8, 6)
# axes = []
# for i in range(8):
#     for j in range(6):
#         #if i+j!=6:
#         axes.append(fig.add_subplot(gs1[i,j]))
#
# for i in range(1,46,2):
#     In1, Out1 = brakets[i]
#     In2, Out2 = brakets[i+1]
#
#     I_test1 = zeros(52)
#     I_test2 = zeros(52)
#
#     for g in range(52):
#         I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real
#         I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real
#
#     n = '8'+str(g)
#     axes[i-1].plot(I_test1, label = 'It')
#     axes[i-1].plot(I_exp_2[i][:,1], label = 'Ie')
#     axes[i-1].set_title('$I_{'+str(i)+'}$')
#     axes[i-1].set_ylim(0, 1)
#     axes[i].plot(I_test2, label = 'It')
#     axes[i].plot(I_exp_2[i+1][:,1], label = 'Ie')
#     axes[i].set_title('$I_{'+str(i+1)+'}$')
#     axes[i].set_ylim(0, 1)

# %% [markdown]
# ## Búsqueda de una combinación de estados de polarización que generen modulación sólo de fase

# %% [markdown]
# Script para encontrar la fase vs nivel de gris introducida por la matriz de Jones del modulador. Estoy probando una forma alternativa en la cual no hago uso de la función "arctan" para obtener la fase introducida por la matriz de Jones antes de encontrar el parámetro beta.
# En vez de eso estoy extrayendo el ángulo del valor que se produce cuando el ket es multiplicado por la matriz M.

# %%
from numpy import arctan,arctan2, info

phi = zeros(52)

## Sección que sigue lo usado por I. Moreno, dónde a partir de una formula 
## y las variables X,Y,Z,w del modulador se extrae la fase.

#chi1 = 0#pi/4#0.3490658503988659#-0.43307956358421984#0.2181361052344816
#chi2 = 0#pi/4#0.3490658503988659#0.59291218452902072#0.63376524318875027
#for i in range(0,52):
#    phi[i] = arctan((Y[i]*cos(chi1+chi2)+W[i]*sin(chi1+chi2))/  \
#		            (X[i]*cos(chi1-chi2)+Z[i]*sin(chi1+chi2)))
fig1 = figure()   
for i in range(1,71):
    
    In, Out =brakets[i]
    
    for g in range(52):
        ket2 = Out.H*M[g]*In
        phi[g] = angle(ket2)
        if g>0 and phi[g]-phi[g-1]>pi:
               phi[g] =phi[g]-2*pi
        elif g>0 and phi[g]-phi[g-1] <- pi:
               phi[g] =phi[g]+2*pi
    
             
    phi = phi - phi[0]
    plot(phi,color = 'r')
    image = loadtxt("In-fourier{0}_fase".format(i))
    #image = loadtxt('If1-52_fase')#"Im{0}_fase".format(i))
    plot(image[::,1],color = 'b')
    beta = image[::,1]-phi
    plot(beta,color = 'g')
show()

# %%
def measure_best_modulation(x0, Jones_matrix, beta, a, b):
    """ Function for finding a configuration where phase modulation 
    is maximum and intensity variation is a minimum
    
    x0: Are the variables that we will vary s a list that includes 
        the parameters for input and output of the braket.
        
    Jones_matrix: Is the matrix that we obtained by doing the 
                characterization of the SLM.
    
    beta: Is the global phase by gray level that the SLM introduces.
    
    a, b: Are weights used to give more or less priority to a state where 
          flatness of the intensity curve is prioritized or range of phase
          modulation is.
    """

    chi2,phi2,chi1,phi1 = x0
    from numpy import arctan2
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    
    In, Out =intensity([ chi2,   phi2],     [chi1,phi1])
    
    phi_t = zeros(52)
    I = zeros(52)
    cambio = 0
    for g in range(52):
        ket2 = Out.H*exp(1j*beta[g])*M[g]*In # Beta was negative.
        I[g] = (ket2.H*ket2)[0,0].real
        phi_t[g] = arctan2(ket2.imag,ket2.real)
    #plot(phi_t)
    for g in range(52):
        if g>0 and  phi_t[g] - phi_t[g-1] > pi-0.1:
            phi_t[g:] = phi_t[g:]-2*pi
        if g>0 and  phi_t[g] - phi_t[g-1] < -pi+0.1:
            phi_t[g:] = phi_t[g:]+2*pi
    
    phi_t = phi_t - phi_t[0]
    
    p = (max(I)-min(I))/average(I)
    q = max(phi_t)-min(phi_t)
    plot(phi_t)
    return p**a/q**b 

bnds = ((-pi/1, pi/1), (-pi, pi),(-pi/1, pi/1), (-pi/1, pi/1))
#bnds = ((-pi, pi),(-pi, pi), (-pi/2, pi/2))

from scipy.optimize import fmin_l_bfgs_b
res = fmin_l_bfgs_b(measure_best_modulation,[ pi/8,0,pi/8,0],\
                    fprime=None,approx_grad=1,  args = (M,beta,2,1), pgtol=1e-05,bounds =bnds)

#res = minimize(measure_modulation,[ .5,  0.5,  0.5, 0.5], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res[0]

res
# Out:
# (array([ 0.6733867 ,  0.06389958,  0.05820086,  0.08672842]),
#  0.25950472243448752,
#  {'funcalls': 52,
#   'grad': array([ 1.35331015, -0.26774696, -0.072496  ,  0.03598206]),
#   'nit': 7,
#   'task': b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH',
#   'warnflag': 0})

# %%
chi2,phi2,chi1,phi1 = res[0]
#chi2,phi2,chi1,phi1 = [pi/4,pi/2,0,0]
In, Out =intensity([ chi2, phi2],     [chi1,phi1])
print(In, Out)
phi1 = zeros(52)
phi2 = zeros(52)
phi_t = zeros(52)
I = zeros(52)
for g in range(52):
    #*exp(1j*-beta[g])
    ket2 = Out.H*exp(1j*beta[g])*M[g]*In
    #print(ket2)
    I[g] = (ket2.H*ket2)[0,0].real
    phi_t[g] = arctan2(ket2.imag,ket2.real)
#for g in range(52):
    #print('g',g,'phi_t[g] - phi_t[g-1]',phi_t[g] - phi_t[g-1])
    #print('phi_t[g]',phi_t[g],'phi_t[g-1]', phi_t[g-1])
    
    #if g>1 and  phi_t[g] - phi_t[g-1] > pi:
    #    phi_t[g:] = phi_t[g:]-2*pi
    #if g>1 and  phi_t[g] - phi_t[g-1] < -pi:
    #    phi_t[g:] = phi_t[g:]+2*pi
figure()
phi_t = phi_t - phi_t[0]
plot(phi_t)
figure()
plot(I)
abs(max(phi_t)-min(phi_t))
# Out:
# [[ 0.99830681+0.j       ]
#  [ 0.05794938+0.0050385j]] [[ 0.78171408+0.j        ]
#  [ 0.62236422+0.03982303j]]
# 1.3279415167950483

# %%
phi_t
# Out:
# array([ 0.        , -0.00906761, -0.01752449, -0.02694517, -0.0408358 ,
#        -0.0548766 , -0.0671011 , -0.07997509, -0.09585289, -0.10965102,
#        -0.12536067, -0.1468701 , -0.16983571, -0.18639196, -0.20850758,
#        -0.23605685, -0.26116633, -0.29448075, -0.32520588, -0.53281443,
#        -0.53290007, -0.36312432, -0.40506533, -0.55462938, -0.58646472,
#        -0.62687606, -0.67789514, -0.74146437, -0.81570305, -0.89128711,
#        -0.9746485 , -1.07000973, -1.17582988, -1.28428324, -1.40026976,
#        -1.52806159, -1.66521317, -1.79878816, -1.93167847, -2.07969118,
#        -2.23304315, -2.37569094, -2.54305907, -2.69994249, -2.85883676,
#        -3.02885746, -3.2069724 , -3.37769085, -3.53858199, -3.677627  ,
#        -3.42866076, -3.96559677])

# %%
plot(phi_t)

# %%
phi_t[-5]-phi_t[-6]
# Out:
# -0.10512572422938016

# %%
deg2rad(20)
# Out:
# 0.3490658503988659

# %%
plot(phi_t[::-1])

# %% [raw]
# La función que esta comentntado debajo hace un barrido dobre muchos estados de entrada y salida hasta llegar a una combinación que sea relativamente buena. Lo comenté porque no es muy bueno.

# %% [raw]
# def get_optimal_state(Jones_matrix):
#     """ Function for finding a configuration where the amplitude
#     is not modulated"""
#     def intensity(bra,ket):
#         In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
#         Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
#         return In, Out
#
#     optimal = {'chi1':0,'chi2':0,'theta1':0,'theta2':0,'value':0 }
#     for chi1 in linspace(0,pi,20):
#         for chi2 in linspace(0,pi,20):
#             for theta1 in linspace(0,pi,10):
#                 for theta2 in linspace(0,pi,10):
#                     I_sim = zeros(52)
#                     for g in range(52):
#                         In,Out = intensity([chi2,theta2],[chi1,theta1])
#                         I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
#                     p = (max(I_sim)-min(I_sim))/average(I_sim)
#                     if 1/p >  optimal['value']:
#                         optimal = {'chi1':chi1,'chi2':chi2,'theta1':theta1,'theta2':theta2,'value':p }
#     return optimal
# optimal = get_optimal_state(M)

# %% [markdown]
# Función que sólo optimiza para que la intensidad

# %%
def measure_flatness(x0,Jones_matrix):
    """ Function for finding a configuration where the amplitude
    is not modulated"""
    chi2,phi2,chi1,phi1 = x0
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    I_sim = zeros(52)
    for g in range(52):
        In,Out = intensity([chi2,phi2],[chi1,phi1])
        I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
    return  (max(I_sim)-min(I_sim))/average(I_sim)

bnds = ((-pi/1, pi/1), (-pi/2, pi/2),(-pi/1, pi/1), (-pi/1, pi/1))
res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res.x
res
# Out:
#      fun: 0.023664278776302113
#     njev: 46
#      jac: array([-0.26689757,  0.01370353,  0.24562327,  0.06959528,  0.        ])
#     nfev: 367
#  message: 'Optimization terminated successfully.'
#  success: True
#        x: array([ 0.62474371, -1.45401152, -0.59426028,  1.76220768])
#   status: 0
#      nit: 46

# %%
I_sim = zeros(52)
for g in range(52):
    In,Out = intensity([chi2,phi2],[chi1,phi1])
    I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
figure()
plot(I_sim)
ylim((0,1))
# Out:
# (0, 1)

# %%
from numpy import arctan, info
phi = zeros(52)
#chi1 = -0.43307956358421984#0.2181361052344816
#chi2 = 0.59291218452902072#0.63376524318875027
for i in range(0,52):
    phi[i] = arctan((Y[i]*cos(chi1+chi2)+W[i]*sin(chi1+chi2))/\
		            X[i]*cos(chi1-chi2)+Z[i]*sin(chi1+chi2))
figure()
plot(phi)
max(phi)-min(phi)
# Out:
# 2.8906956725682047

# %%
def measure_modulation(x0,Jones_matrix):
    """ Function for finding a configuration where phase modulation 
    is maximum"""
    chi2,phi2,chi1,phi1 = x0
    
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    
    In, Out =intensity([ chi2,   phi2],     [chi1,phi1])
    
    phi_t = zeros(52)
    I = zeros(52)
    for g in range(52):
        ket2 = Out.H*exp(1j*-beta[g])*M[g]*In
        I[g] = (ket2.H*ket2)[0,0].real
        phi_t[g] = (angle(ket2))
        if g>0 and phi_t[g]-phi_t[g-1]>pi:
           phi_t[g] =phi_t[g]-2*pi
        elif g>0 and phi_t[g]-phi_t[g-1] <- pi:
           phi_t[g] =phi_t[g]+2*pi
    print(max(phi_t)-min(phi_t))
    print(1/(max(phi_t)-min(phi_t)))
    return  1/(max(phi_t)-min(phi_t))

bnds = ((-pi/1, pi/1), (-pi, pi),(-pi/1, pi/1), (-pi/1, pi/1))
#bnds = ((-pi, pi),(-pi, pi), (-pi/2, pi/2))

from scipy.optimize import fmin_l_bfgs_b
res = fmin_l_bfgs_b(measure_modulation,[ .5,  0.5,  0.5, 0.5],fprime=None,approx_grad=1,  args = (M,), pgtol=1e-05,bounds =bnds)

#res = minimize(measure_modulation,[ .5,  0.5,  0.5, 0.5], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res[0]

res
# Out:
# 4.4789032867
# 0.223268942415
# 4.4789032867
# 0.223268942415
# 4.47890328234
# 0.223268942632
# 4.47890329992
# 0.223268941756
# 4.47890331613
# 0.223268940948
# 4.47890329274
# 0.223268942114
# 5.08379902729
# 0.196703291108
# 5.08379902729
# 0.196703291108
# 5.08379900632
# 0.196703291919
# 5.08379903666
# 0.196703290746
# 5.08379906131
# 0.196703289792
# 5.08379902534
# 0.196703291184
# 2.89871434298
# 0.344980526426
# 2.89871434298
# 0.344980526426
# 2.89871434934
# 0.344980525669
# 2.89871434244
# 0.34498052649
# 2.89871434307
# 0.344980526415
# 2.8987143358
# 0.344980527281
# 6.01275409933
# 0.166313137621
# 6.01275409933
# 0.166313137621
# 6.01275408333
# 0.166313138063
# 6.01275409711
# 0.166313137682
# 6.012754111
# 0.166313137298
# 6.01275409022
# 0.166313137872
# 6.20937226195
# 0.161046875242
# 6.20937226195
# 0.161046875242
# 6.2093722498
# 0.161046875557
# 6.2093722586
# 0.161046875329
# 6.20937226928
# 0.161046875052
# 6.20937225367
# 0.161046875456
# 6.47279121974
# 0.154492855717
# 6.47279121974
# 0.154492855717
# 6.47279121263
# 0.154492855887
# 6.47279121561
# 0.154492855816
# 6.47279122269
# 0.154492855647
# 6.47279121397
# 0.154492855855
# 6.6500169748
# 0.150375556001
# 6.6500169748
# 0.150375556001
# 6.65001697089
# 0.150375556089
# 6.65001696981
# 0.150375556114
# 6.65001697631
# 0.150375555967
# 6.65001697284
# 0.150375556045
# 3.41505548637
# 0.292821010959
# 3.41505548637
# 0.292821010959
# 3.41505545506
# 0.292821013644
# 3.41505549044
# 0.29282101061
# 3.41505549253
# 0.29282101043
# 3.41505546435
# 0.292821012847
# 6.65185077487
# 0.150334100064
# 6.65185077487
# 0.150334100064
# 6.65185077101
# 0.150334100151
# 6.65185076986
# 0.150334100177
# 6.65185077641
# 0.150334100029
# 6.65185077297
# 0.150334100107
# 6.6536667751
# 0.15029306904
# 6.6536667751
# 0.15029306904
# 6.65366677129
# 0.150293069126
# 6.65366677008
# 0.150293069154
# 6.65366677668
# 0.150293069004
# 6.65366677328
# 0.150293069081
# 6.86562297
# 0.145653206471
# 6.86562297
# 0.145653206471
# 6.86562296455
# 0.145653206586
# 6.86562296008
# 0.145653206681
# 6.86562298793
# 0.14565320609
# 6.86562298087
# 0.14565320624
# 6.87044369403
# 0.145551007262
# 6.87044369403
# 0.145551007262
# 6.87044368825
# 0.145551007384
# 6.87044368395
# 0.145551007475
# 6.87044371272
# 0.145551006866
# 6.87044370527
# 0.145551007024
# 6.87550847506
# 0.145443788431
# 6.87550847506
# 0.145443788431
# 6.87550846891
# 0.145443788561
# 6.87550846482
# 0.145443788647
# 6.87550849458
# 0.145443788018
# 6.87550848669
# 0.145443788185
# 3.43897710078
# 0.290784140369
# 3.43897710078
# 0.290784140369
# 3.43897711621
# 0.290784139064
# 3.4389771067
# 0.290784139869
# 3.43897709252
# 0.290784141068
# 3.43897708577
# 0.290784141638
# 6.87698958892
# 0.145412463851
# 6.87698958892
# 0.145412463851
# 6.87698958265
# 0.145412463983
# 6.87698957862
# 0.145412464068
# 6.87698960868
# 0.145412463433
# 6.87698960066
# 0.145412463602
# 6.87848362985
# 0.145380879539
# 6.87848362985
# 0.145380879539
# 6.87848362347
# 0.145380879673
# 6.87848361951
# 0.145380879757
# 6.87848364987
# 0.145380879116
# 6.87848364171
# 0.145380879288
# 3.55331779669
# 0.281427121698
# 3.55331779669
# 0.281427121698
# 3.55331784085
# 0.281427118201
# 3.55331780778
# 0.281427120819
# 3.55331776944
# 0.281427123856
# 3.55331777632
# 0.281427123311
# 6.87889453908
# 0.145372195244
# 6.87889453908
# 0.145372195244
# 6.87889453267
# 0.14537219538
# 6.87889452873
# 0.145372195463
# 6.87889455916
# 0.14537219482
# 6.87889455097
# 0.145372194993
# 6.87930504148
# 0.145363520584
# 6.87930504148
# 0.145363520584
# 6.87930503504
# 0.14536352072
# 6.87930503111
# 0.145363520803
# 6.87930506163
# 0.145363520158
# 6.8793050534
# 0.145363520332
# 6.95999289917
# 0.143678307505
# 6.95999289917
# 0.143678307505
# 6.95999288393
# 0.14367830782
# 6.95999288613
# 0.143678307774
# 6.95999293546
# 0.143678306756
# 6.9599929173
# 0.143678307131
# 6.95999289917
# 0.143678307505
# 6.95999289917
# 0.143678307505
# 6.95999288393
# 0.14367830782
# 6.95999288613
# 0.143678307774
# 6.95999293546
# 0.143678306756
# 6.9599929173
# 0.143678307131
# 5.1732066122
# 0.193303704059
# 5.1732066122
# 0.193303704059
# 5.17320659845
# 0.193303704573
# 5.17320662622
# 0.193303703535
# 5.17320662555
# 0.19330370356
# 5.1732066122
# 0.193303704059
# 3.60037924186
# 0.277748518371
# 3.60037924186
# 0.277748518371
# 3.60037922852
# 0.2777485194
# 3.6003792405
# 0.277748518476
# 3.60037923703
# 0.277748518743
# 3.60037923077
# 0.277748519226
# 7.03066220647
# 0.14223411261
# 7.03066220647
# 0.14223411261
# 7.03066217998
# 0.142234113146
# 7.03066219149
# 0.142234112913
# 7.0306622606
# 0.142234111515
# 7.03066222935
# 0.142234112147
# 3.51394199335
# 0.284580679446
# 3.51394199335
# 0.284580679446
# 3.51394202945
# 0.284580676522
# 3.51394200337
# 0.284580678634
# 3.5139419719
# 0.284580681182
# 3.51394197404
# 0.284580681009
# 7.03093467453
# 0.142228600647
# 7.03093467453
# 0.142228600647
# 7.03093464799
# 0.142228601184
# 7.03093465954
# 0.14222860095
# 7.03093472874
# 0.142228599551
# 7.03093469743
# 0.142228600184
# 7.03120643352
# 0.142223103454
# 7.03120643352
# 0.142223103454
# 7.03120640694
# 0.142223103992
# 7.03120641853
# 0.142223103757
# 7.03120648781
# 0.142223102356
# 7.03120645644
# 0.14222310299
# 3.55048013854
# 0.281652047323
# 3.55048013854
# 0.281652047323
# 3.55048018433
# 0.281652043691
# 3.55048014997
# 0.281652046417
# 3.55048011013
# 0.281652049577
# 3.5504801178
# 0.281652048968
# 7.03127553589
# 0.142221705706
# 7.03127553589
# 0.142221705706
# 7.03127550929
# 0.142221706244
# 7.03127552089
# 0.142221706009
# 7.03127559019
# 0.142221704607
# 7.03127555881
# 0.142221705242
# 7.03134450286
# 0.142220310723
# 7.03134450286
# 0.142220310723
# 7.03134447625
# 0.142220311262
# 7.03134448786
# 0.142220311027
# 7.03134455718
# 0.142220309625
# 7.03134452578
# 0.14222031026
# 7.059798383
# 0.141647104598
# 7.059798383
# 0.141647104598
# 7.0597983508
# 0.141647105244
# 7.05979836725
# 0.141647104914
# 7.05979844546
# 0.141647103345
# 7.05979840773
# 0.141647104102
# 7.05982051328
# 0.14164666058
# 7.05982051328
# 0.14164666058
# 7.05982048108
# 0.141646661226
# 7.05982049752
# 0.141646660896
# 7.05982057575
# 0.141646659327
# 7.05982053801
# 0.141646660084
# 7.05984261555
# 0.141646217126
# 7.05984261555
# 0.141646217126
# 7.05984258335
# 0.141646217772
# 7.0598425998
# 0.141646217442
# 7.05984267803
# 0.141646215873
# 7.05984264029
# 0.14164621663
# 7.07557109721
# 0.141331347853
# 7.07557109721
# 0.141331347853
# 7.07557106167
# 0.141331348563
# 7.07557108105
# 0.141331348176
# 7.07557116441
# 0.141331346511
# 7.07557112292
# 0.14133134734
# 7.07557109721
# 0.141331347853
# 7.07557109721
# 0.141331347853
# 7.07557106167
# 0.141331348563
# 7.07557108105
# 0.141331348176
# 7.07557116441
# 0.141331346511
# 7.07557112292
# 0.14133134734
# 6.15354983648
# 0.162507825007
# 6.15354983648
# 0.162507825007
# 6.15354983334
# 0.16250782509
# 6.15354985108
# 0.162507824622
# 6.15354983222
# 0.16250782512
# 6.15354983648
# 0.162507825007
# 3.51383327757
# 0.284589484192
# 3.51383327757
# 0.284589484192
# 3.51383326937
# 0.284589484856
# 3.51383327433
# 0.284589484454
# 3.5138332716
# 0.284589484676
# 3.51383326902
# 0.284589484884
# 3.39705373252
# 0.294372735534
# 3.39705373252
# 0.294372735534
# 3.39705374548
# 0.294372734412
# 3.39705373779
# 0.294372735078
# 3.39705372579
# 0.294372736118
# 3.39705371806
# 0.294372736787
# 7.07938134337
# 0.141255280864
# 7.07938134337
# 0.141255280864
# 7.07938130698
# 0.14125528159
# 7.07938132712
# 0.141255281188
# 7.07938141174
# 0.1412552795
# 7.0793813693
# 0.141255280346
# 3.5565948156
# 0.281167816928
# 3.5565948156
# 0.281167816928
# 3.5565951133
# 0.281167793393
# 3.5565949057
# 0.281167809805
# 3.55659454775
# 0.281167838103
# 3.5565946594
# 0.281167829277
# 7.0793816932
# 0.141255273884
# 7.0793816932
# 0.141255273884
# 7.07938165681
# 0.14125527461
# 7.07938167695
# 0.141255274208
# 7.07938176157
# 0.14125527252
# 7.07938171912
# 0.141255273366
# 7.07938204296
# 0.141255266905
# 7.07938204296
# 0.141255266905
# 7.07938200657
# 0.141255267631
# 7.07938202671
# 0.141255267229
# 7.07938211133
# 0.141255265541
# 7.07938206888
# 0.141255266388
# 3.58700101199
# 0.278784420929
# 3.58700101199
# 0.278784420929
# 3.58700373546
# 0.278784209259
# 3.58700196909
# 0.278784346543
# 3.58699839627
# 0.278784624225
# 3.58699936791
# 0.278784548708
# 7.07938213321
# 0.141255265104
# 7.07938213321
# 0.141255265104
# 7.07938209682
# 0.14125526583
# 7.07938211696
# 0.141255265428
# 7.07938220158
# 0.14125526374
# 7.07938215913
# 0.141255264587
# 7.07938222345
# 0.141255263304
# 7.07938222345
# 0.141255263304
# 7.07938218706
# 0.14125526403
# 7.0793822072
# 0.141255263628
# 7.07938229182
# 0.141255261939
# 7.07938224938
# 0.141255262786
# 3.64230730532
# 0.274551243532
# 3.64230730532
# 0.274551243532
# 3.64231104812
# 0.274550961406
# 3.64230838939
# 0.274551161817
# 3.64230368606
# 0.274551516346
# 3.64230544364
# 0.274551383862
# 7.07938224658
# 0.141255262842
# 7.07938224658
# 0.141255262842
# 7.07938221019
# 0.141255263568
# 7.07938223033
# 0.141255263166
# 7.07938231495
# 0.141255261478
# 7.07938227251
# 0.141255262325
# 7.07938226972
# 0.14125526238
# 7.07938226972
# 0.14125526238
# 7.07938223333
# 0.141255263106
# 7.07938225347
# 0.141255262705
# 7.07938233809
# 0.141255261016
# 7.07938229564
# 0.141255261863
# 7.07986133888
# 0.141245704137
# 7.07986133888
# 0.141245704137
# 7.07986130238
# 0.141245704865
# 7.07986132262
# 0.141245704461
# 7.0798614074
# 0.14124570277
# 7.07986136483
# 0.141245703619
# 7.07986133888
# 0.141245704137
# 7.07986133888
# 0.141245704137
# 7.07986130238
# 0.141245704865
# 7.07986132262
# 0.141245704461
# 7.0798614074
# 0.14124570277
# 7.07986136483
# 0.141245703619
# 6.15544999718
# 0.162457659547
# 6.15544999718
# 0.162457659547
# 6.15544999394
# 0.162457659632
# 6.15545001153
# 0.162457659168
# 6.15544999221
# 0.162457659678
# 6.15544999718
# 0.162457659547
# 3.51536105994
# 0.28446580108
# 3.51536105994
# 0.28446580108
# 3.51536105181
# 0.284465801737
# 3.51536105662
# 0.284465801348
# 3.51536105388
# 0.28446580157
# 3.51536105143
# 0.284465801768
# 3.39322546593
# 0.294704849424
# 3.39322546593
# 0.294704849424
# 3.39322547829
# 0.294704848351
# 3.39322547103
# 0.294704848981
# 3.39322545953
# 0.294704849981
# 3.39322545165
# 0.294704850665
# 3.55528253916
# 0.281271597682
# 3.55528253916
# 0.281271597682
# 3.55528258637
# 0.281271593947
# 3.55528255077
# 0.281271596763
# 3.55528250971
# 0.281271600012
# 3.55528251824
# 0.281271599337
# 7.07986174335
# 0.141245696067
# 7.07986174335
# 0.141245696067
# 7.07986170685
# 0.141245696795
# 7.07986172709
# 0.141245696392
# 7.07986181187
# 0.1412456947
# 7.07986176931
# 0.14124569555
# 7.07986214774
# 0.141245688
# 7.07986214774
# 0.141245688
# 7.07986211125
# 0.141245688728
# 7.07986213148
# 0.141245688324
# 7.07986221626
# 0.141245686633
# 7.0798621737
# 0.141245687482
# 3.56334619389
# 0.280635095662
# 3.56334619389
# 0.280635095662
# 3.56334650304
# 0.280635071314
# 3.5633462854
# 0.280635088455
# 3.56334591521
# 0.28063511761
# 3.56334603541
# 0.280635108144
# 7.07986224946
# 0.14124568597
# 7.07986224946
# 0.14124568597
# 7.07986221296
# 0.141245686698
# 7.0798622332
# 0.141245686295
# 7.07986231798
# 0.141245684603
# 7.07986227541
# 0.141245685453
# 7.07986235116
# 0.141245683941
# 7.07986235116
# 0.141245683941
# 7.07986231466
# 0.141245684669
# 7.0798623349
# 0.141245684266
# 7.07986241968
# 0.141245682574
# 7.07986237711
# 0.141245683424
# 3.60841737918
# 0.277129803711
# 3.60841737918
# 0.277129803711
# 3.60842048127
# 0.277129565468
# 3.60841838695
# 0.277129726314
# 3.60841439113
# 0.277130033196
# 3.60841564831
# 0.277129936644
# 7.07986237748
# 0.141245683416
# 7.07986237748
# 0.141245683416
# 7.07986234098
# 0.141245684144
# 7.07986236121
# 0.141245683741
# 7.07986244599
# 0.141245682049
# 7.07986240343
# 0.141245682899
# 7.07986240379
# 0.141245682891
# 7.07986240379
# 0.141245682891
# 7.07986236729
# 0.14124568362
# 7.07986238753
# 0.141245683216
# 7.07986247231
# 0.141245681524
# 7.07986242974
# 0.141245682374
# 3.63978407262
# 0.27474157259
# 3.63978407262
# 0.27474157259
# 3.63978776624
# 0.274741293785
# 3.63978515124
# 0.274741491173
# 3.63978050188
# 0.27474184212
# 3.6397822203
# 0.274741712409
# 7.07986241045
# 0.141245682758
# 7.07986241045
# 0.141245682758
# 7.07986237396
# 0.141245683487
# 7.07986239419
# 0.141245683083
# 7.07986247897
# 0.141245681391
# 7.07986243641
# 0.141245682241
# 7.07986241712
# 0.141245682625
# 7.07986241712
# 0.141245682625
# 7.07986238062
# 0.141245683354
# 7.07986240086
# 0.14124568295
# 7.07986248564
# 0.141245681258
# 7.07986244307
# 0.141245682108
# 3.65744308918
# 0.273415054074
# 3.65744308918
# 0.273415054074
# 3.65744713488
# 0.273414751635
# 3.657444206
# 0.273414970585
# 3.65743917111
# 0.273415346973
# 3.6574411713
# 0.273415197446
# 7.0798624188
# 0.141245682592
# 7.0798624188
# 0.141245682592
# 7.0798623823
# 0.14124568332
# 7.07986240254
# 0.141245682916
# 7.07986248732
# 0.141245681225
# 7.07986244475
# 0.141245682074
# 7.07986242047
# 0.141245682558
# 7.07986242047
# 0.141245682558
# 7.07986238398
# 0.141245683287
# 7.07986240421
# 0.141245682883
# 7.07986248899
# 0.141245681191
# 7.07986244643
# 0.141245682041
# 7.07999136573
# 0.141243110103
# 7.07999136573
# 0.141243110103
# 7.0799913292
# 0.141243110832
# 7.07999134946
# 0.141243110428
# 7.07999143429
# 0.141243108736
# 7.07999139169
# 0.141243109585
# 7.07999136615
# 0.141243110095
# 7.07999136615
# 0.141243110095
# 7.07999132962
# 0.141243110824
# 7.07999134988
# 0.141243110419
# 7.0799914347
# 0.141243108727
# 7.07999139211
# 0.141243109577
# 3.32998444526
# 0.300301703038
# 3.32998444526
# 0.300301703038
# 3.32998441714
# 0.300301705573
# 3.32998444692
# 0.300301702888
# 3.32998445106
# 0.300301702515
# 3.32998442676
# 0.300301704706
# 3.53603154044
# 0.282802907317
# 3.53603154044
# 0.282802907317
# 3.53603158274
# 0.282802903934
# 3.53603155132
# 0.282802906446
# 3.53603151465
# 0.28280290938
# 3.53603152026
# 0.282802908931
# 7.07989182172
# 0.141245095996
# 7.07989182172
# 0.141245095996
# 7.07989178522
# 0.141245096724
# 7.07989180546
# 0.14124509632
# 7.07989189025
# 0.141245094629
# 7.07989184768
# 0.141245095478
# 7.07992226104
# 0.141244488729
# 7.07992226104
# 0.141244488729
# 7.07992222453
# 0.141244489457
# 7.07992224478
# 0.141244489053
# 7.07992232958
# 0.141244487361
# 7.079922287
# 0.141244488211
# 3.54670198461
# 0.28195207952
# 3.54670198461
# 0.28195207952
# 3.5467020296
# 0.281952075944
# 3.5467019959
# 0.281952078623
# 3.54670195683
# 0.281952081729
# 3.54670196402
# 0.281952081157
# 7.07992990123
# 0.141244336307
# 7.07992990123
# 0.141244336307
# 7.07992986471
# 0.141244337036
# 7.07992988496
# 0.141244336632
# 7.07992996977
# 0.14124433494
# 7.07992992718
# 0.141244335789
# 7.07993753542
# 0.141244184005
# 7.07993753542
# 0.141244184005
# 7.07993749891
# 0.141244184734
# 7.07993751916
# 0.14124418433
# 7.07993760397
# 0.141244182638
# 7.07993756138
# 0.141244183487
# 3.55228359086
# 0.281509055913
# 3.55228359086
# 0.281509055913
# 3.55228363729
# 0.281509052234
# 3.55228360236
# 0.281509055002
# 3.552283562
# 0.2815090582
# 3.55228357006
# 0.281509057562
# 7.07993944778
# 0.141244145854
# 7.07993944778
# 0.141244145854
# 7.07993941126
# 0.141244146583
# 7.07993943151
# 0.141244146179
# 7.07993951632
# 0.141244144487
# 7.07993947373
# 0.141244145336
# 7.07994135934
# 0.141244107719
# 7.07994135934
# 0.141244107719
# 7.07994132283
# 0.141244108447
# 7.07994134308
# 0.141244108043
# 7.07994142789
# 0.141244106351
# 7.0799413853
# 0.141244107201
# 3.55513929375
# 0.281282930814
# 3.55513929375
# 0.281282930814
# 3.55513934092
# 0.281282927083
# 3.55513930535
# 0.281282929897
# 3.55513926434
# 0.281282933142
# 3.55513927284
# 0.281282932469
# 7.07994183771
# 0.141244098175
# 7.07994183771
# 0.141244098175
# 7.07994180119
# 0.141244098904
# 7.07994182145
# 0.1412440985
# 7.07994190625
# 0.141244096808
# 7.07994186367
# 0.141244097657
# 7.07994231598
# 0.141244088634
# 7.07994231598
# 0.141244088634
# 7.07994227946
# 0.141244089362
# 7.07994229971
# 0.141244088958
# 7.07994238452
# 0.141244087266
# 7.07994234194
# 0.141244088116
# 3.56237107306
# 0.280711913355
# 3.56237107306
# 0.280711913355
# 3.5623713801
# 0.280711889161
# 3.56237116421
# 0.280711906173
# 3.5623707964
# 0.280711935156
# 3.56237091516
# 0.280711925798
# 7.07994243622
# 0.141244086235
# 7.07994243622
# 0.141244086235
# 7.07994239971
# 0.141244086963
# 7.07994241996
# 0.141244086559
# 7.07994250477
# 0.141244084867
# 7.07994246218
# 0.141244085717
# 7.07994255646
# 0.141244083836
# 7.07994255646
# 0.141244083836
# 7.07994251994
# 0.141244084565
# 7.07994254019
# 0.141244084161
# 7.079942625
# 0.141244082469
# 7.07994258242
# 0.141244083318
# 3.60122969482
# 0.277682926318
# 3.60122969482
# 0.277682926318
# 3.60123263955
# 0.277682699257
# 3.60123067633
# 0.277682850636
# 3.60122686132
# 0.277683144803
# 3.60122800894
# 0.277683056312
# 7.07994258745
# 0.141244083218
# 7.07994258745
# 0.141244083218
# 7.07994255094
# 0.141244083946
# 7.07994257119
# 0.141244083542
# 7.079942656
# 0.14124408185
# 7.07994261341
# 0.1412440827
# 7.07994261845
# 0.141244082599
# 7.07994261845
# 0.141244082599
# 7.07994258193
# 0.141244083328
# 7.07994260219
# 0.141244082924
# 7.07994268699
# 0.141244081232
# 7.07994264441
# 0.141244082082
# 3.63288913563
# 0.275263010421
# 3.63288913563
# 0.275263010421
# 3.63289267733
# 0.275262742068
# 3.63289019352
# 0.275262930266
# 3.63288571446
# 0.275263269642
# 3.63288731884
# 0.275263148079
# (array([ 0.10082988,  0.39876702,  1.745565  ,  0.22319289]),
#  0.27526301042139517,
#  {'funcalls': 90,
#   'grad': array([ 0.07281461,  0.03244168, -0.13669671, -0.05177834]),
#   'nit': 8,
#   'task': b'ABNORMAL_TERMINATION_IN_LNSRCH',
#   'warnflag': 2})

# %%
def translate(psi,delta):
    psi = psi*180/pi
    delta = delta*180/pi
    return psi, delta
translate(-1.72185039, -1.57079632679)
# Out:
# (-98.6547602999548, -89.99999999971946)

# %% [markdown]
# Test_1_ [ 0.62474371, -1.45401152, -0.59426028,  1.76220768]

# %%
translate(-0.59426028,0.340453803463)
# Out:
# (-34.048605976262564, 19.506566057606314)

# %%
translate(0.62474371,0.101935628366)
# Out:
# (35.79517786034504, 5.840481287385836)

# %% [markdown]
# Newer

# %%
translate(1.5695103,1.01828190734)
# Out:
# (89.92631609231168, 58.343255645113565)

# %% [markdown]
# Test_2 array([ 1.24894128,  1.1499534 , -0.91295678, -0.29651299]

# %%
translate(-0.91295678,-0.0632559391956)
# Out:
# (-52.30857037185361, -3.62429834504404)

# %%
translate(1.24894128,1.46618242436)
# Out:
# (71.55906420366681, 84.00606491208704)
