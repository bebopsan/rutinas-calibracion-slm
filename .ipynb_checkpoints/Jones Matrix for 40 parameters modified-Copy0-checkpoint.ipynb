# %% [markdown]
# # Scripts para la construcción de la matriz de Jones usando las medidas experimentales

# %% [markdown]
# Importación de librerias y carga de archivos.

# %%
from sympy import symbols, Matrix
from numpy import loadtxt, zeros, matrix, exp, pi, sqrt, sign, cos, sin
from scipy.optimize import minimize
import matplotlib.gridspec as gridspec
from pylab import *
# %pylab inline

I_exp = {}
I = {}
for i in range(1,41):
   # image = "Imagen{0}_amp".format(i)
    image = "Imagen{0}_amp".format(i)
    I_exp[i] = loadtxt(image)    
    I[i] = zeros(52)
    
#I_exp[41] =  loadtxt("In21_amp")
#I[41] = zeros(52)
#I_exp[42] =  loadtxt("In22_amp")
#I[42] = zeros(52)
I_exp_2 = I_exp
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random', 'linalg', 'info', 'fft', 'power', 'draw_if_interactive']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# ## Normalización

# %% [markdown]
# En este punto suceden dos cosas, primero realizo una normalización por pares.
# Asumiendo que cada medida esta antecedida por su estado ortogonal, lo que hago es:
# $$I_i = \frac{I_i^{exp}}{I_i^{exp}+I_{i+1}^{exp}}$$

# %%
# Averaging of intensities
for i in range(1,40,2):
    for g in range(I_exp[i].shape[0]):
        I[i][g] = I_exp[i][g,1]/(I_exp[i][g,1]+I_exp[i+1][g,1])
        I[i+1][g] = I_exp[i+1][g,1]/(I_exp[i][g,1]+I_exp[i+1][g,1])

# %% [markdown]
# Graficación de las curvas de indensidad normalizadas

# %%
fig = figure()
for i in range(1,41):
    plot(I[i],label='I{0}'.format(i))
plot(I[5]+I[6],label='I{0}'.format(i))

show()

# %% [markdown]
# Estas son las curvas equivalentes a las curvas de intensidad que se usan para caracterizar el modulador en el artículo de Moreno.

# %%
#fig = figure()
#plot(I[1],label='I1')
#plot(I[2],label='I2')
#plot(I[4],label='I3')
#plot(I[42],label='I4')
#plot(I[21],label='I5')
#plot(I[22],label='I6')
#plot(I[5],label='I7')
#plot(I[6],label='I7p')
#legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#display(fig)

# %% [markdown]
# ## Definición de X, Y, Z y W

# %% [markdown]
# Siguiendo las fórmulas que se exponen en el artículo de Moreno y Velazques
# encuentro los valores de X, Y, Z, y W, y sus signos.

# %%
X = zeros(52)
Y = zeros(52)
Z = zeros(52)
W = zeros(52)
#for i in range(3,43,2):
#    delta = I[i][0]-I[i+1][0]
#   I[i] = I[i]- delta/2
#    I[i+1] = I[i+1] + delta/2
#for g in range(I[1].shape[0]):
#    X[g] = sqrt( I[1][g]/(1+( (I[5][g]-I[22][g])/(I[4][g]-I[42][g]) )**2) )
#    Y[g] = sqrt( I[1][g]/(1+( (I[4][g]-I[42][g])/(I[5][g]-I[22][g]) )**2) )
#    Z[g] = sqrt( I[2][g]/(1+( (I[4][g]-I[42][g])/(I[21][g]-I[5][g]) )**2) )
#    W[g] = sqrt( I[2][g]/(1+( (I[21][g]-I[5][g])/(I[4][g]-I[42][g]) )**2) )
    
#    sign_Z = sign(I[21][g]-I[5][g])/sign(X[g])
#    if sign(Z[g]) != sign_Z:
#        Z[g] = Z[g]*-1
#    sign_W = sign(I[4][g]-I[42][g])/sign(X[g])
#    if sign(W[g]) != sign_W:
#       W[g] = W[g]*-1
#    sign_Y = sign(I[5][g]-I[22][g])/sign(X[g])
#    if sign(Z[g]) != sign_Y:
#        Y[g] = Y[g]*-1

# %% [markdown]
# Graficas de X, Y, Z y W:

# %%
## figure()
## plot(X,label='X,76,34')
## plot(Y,label='Y,34,76')
## plot(Z,label='Z, 34,57')
## plot(W,label='W, 57,34')
## grid()
## legend()

# %% [markdown]
# ## Matriz de Jones del modulador

# %% [markdown]
# Definición de Brakets siguiendo la formulación de vectores de Jones.

# %%
I_exp = I
def intensity(bra,ket):
    In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
    Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
    return In, Out
brakets = {1:intensity([ 0,   0],     [0,0]),\
           2:intensity([ pi/2,0],     [0,0]),\
           3:intensity([ pi/4,pi/2],  [0,0]),\
           4:intensity([ pi/4,-pi/2],  [0,0]),\
           5:intensity([ pi/4, 0],    [0,0]),\
           6:intensity([-pi/4, 0],    [0,0]),\
           7:intensity([ 3*pi/8, pi/2],  [0,0]),\
           8:intensity([pi/8,-pi/2],[0,0]),\
           9:intensity([ pi/4, pi/4],   [0,0]),\
           10:intensity([3*pi/4, pi/4],[0,0]),\
           11:intensity([ 0,   0],     [pi/2,0]),\
           12:intensity([ pi/2,0],     [pi/2,0]),\
           13:intensity([ pi/4,pi/2],  [pi/2,0]),\
           14:intensity([ pi/4,-pi/2],  [pi/2,0]),\
           15:intensity([ pi/4, 0],    [pi/2,0]),\
           16:intensity([-pi/4, 0],    [pi/2,0]),\
           17:intensity([ 3*pi/8, pi/2],  [pi/2,0]),\
           18:intensity([ pi/8, -pi/2],[pi/2,0]),\
           19:intensity([ pi/4, pi/4],   [pi/2,0]),\
           20:intensity([3*pi/4, pi/4],   [pi/2,0]),\
           21:intensity([ 0,   0],     [pi/4,0]),\
           22:intensity([ pi/2,0],     [pi/4,0]),\
           23:intensity([ pi/4,pi/2],  [pi/4,0]),\
           24:intensity([ pi/4,-pi/2],  [pi/4,0]),\
           25:intensity([ pi/4, 0],    [pi/4,0]),\
           26:intensity([-pi/4, 0],    [pi/4,0]),\
           27:intensity([3*pi/8, pi/2],  [pi/4,0]),\
           28:intensity([pi/8, -pi/2],[pi/4,0]),\
           29:intensity([pi/4, pi/4],   [pi/4,0]),\
           30:intensity([3*pi/4, pi/4],[pi/4,0]),\
           31:intensity([ 0,   0],     [-pi/4,0]),\
           32:intensity([ pi/2,0],     [-pi/4,0]),\
           33:intensity([ pi/4,pi/2],  [-pi/4,0]),\
           34:intensity([ pi/4,-pi/2],  [-pi/4,0]),\
           35:intensity([ pi/4, 0],    [-pi/4,0]),\
           36:intensity([-pi/4, 0],    [-pi/4,0]),\
           37:intensity([3*pi/8, pi/2],  [-pi/4,0]),\
           38:intensity([pi/8, -pi/2],[-pi/4,0]),\
           39:intensity([pi/4, pi/4],   [-pi/4,0]),\
           40:intensity([3*pi/4, pi/4],[-pi/4,0]),\
	       42:intensity([ 0,   0],     [pi/4,pi/2]),\
	       41:intensity([ pi/2,   0],     [pi/4,pi/2]),\
	       43:intensity([ pi/4, pi/2],     [pi/4,pi/2]),\
	       44:intensity([ pi/4, -pi/2],     [pi/4,pi/2]),\
	       45:intensity([ -pi/4, 0],     [pi/4,pi/2]),\
	       46:intensity([ pi/4, 0],     [pi/4,pi/2])}

# %% [markdown]
# Definición de una función a minimizar. Esta función calcula las diferencias cuadradas
# entre las medidas experimentales y las intensidades resultantes de operar con los
# vectores de Jones:

# %%
def min_sq(x0,I_exp,g,alpha,psi,brakets):
    """ Calculates squared differences for a minimization procedure.

    Given the experimental meassures of intensity and arbitrary values for 
    the parameters of an SLM Jones Matrix, this function gives a value to
    minimize. That value tells how close is the estimation of alpha, beta, psi, delta 
    to the value that correctly models the SLM.

    :param alpha,beta,psi,delta: Are a guess of real scalars that conform physical parameters the SLM.
    :param I_exp: Is a dictionary contanining intensities for every polarization state.
    :param g: Is the gray level of the SLM for which we are solving.
    """
    [beta, delta] = x0
    
    R = matrix([[ cos(alpha), sin(alpha)],\
                [-sin(alpha), cos(alpha)]])
    R_global = matrix([[ cos(psi), sin(psi)],\
                       [-sin(psi), cos(psi)]])
    
    gamma = sqrt(alpha**2 + beta**2)
    x = cos(gamma)
    y = beta*sin(gamma)/gamma
    z = alpha*sin(gamma)/gamma
    
    M_xyz = matrix([[ x - y*1j, z     ],\
                    [-z       , x+y*1j]])
    
    M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
    
    W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                       [      0        , exp(1j*delta)]])
    M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
    
    M = R_global.transpose()*M_LCDp*R_global
    
    min_sum = 0
    I_sim = {}
    for i in range(1,41):
        #if i%2 !=0:
	#if i in [1,2,5,6,11,12,15,16,21,22,25,26,31,32,36,35]:
        #if i in [1,2,3,4,5,6,11,12,15,16,21,22,25,26,31,33,35,36]:
        #if i in []:
        if i not in []:
            In, Out = brakets[i]
            I_sim[i] = (In.H*M.H*Out * Out.H*M*In)
            min_sum += ((I_sim[i]-I_exp[i][g])**2)[0,0].real
            #min_sum += (sqrt(abs(I_sim[i]**2-I_exp[i][g]**2)))[0,0].realqq
    
    return min_sum

# %% [markdown]
# Si probamos con unos valores iniciales cualquiera debe devolver un número escalar:

# %%
min_sq([2.6,0],I_exp,0,-pi/2,pi/4, brakets)
# Out:
# 11.362887461095129

# %% [markdown]
# Minimización con restricciónes de caja. El método que mejor hace la minimización es el SLSQP:

# %%
M = {}
bnds = ((-pi/4, 2*pi), (0, 10))
cons = ({'type': 'eq', 'fun': lambda x:  x[0]**2+x[1]**2+x[2]**2+x[3]**2 - 1})
from scipy.optimize import fmin_l_bfgs_b
beta,delta = pi, 0.5
Beta, Delta = [],[]
alpha,psi = -1.63400317439, -0.627396281551
for g in range(51,-1,-1):   
    #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
    #res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'Nelder-Mead')
    res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP',bounds =bnds)
    #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')        
    #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
    #res = fmin_l_bfgs_b(min_sq,[ 2.6,  0],fprime=None,approx_grad=1, args = (I_exp,g,alpha,psi,brakets),pgtol=1e-05)
    
    #beta,delta = res[0]
    beta,delta = res.x
    if delta > pi/4:
            delta = 0
    Beta.append(beta)
    Delta.append(delta)
    R = matrix([[ cos(alpha), sin(alpha)],\
                [-sin(alpha), cos(alpha)]])
    R_global = matrix([[ cos(psi), sin(psi)],\
                       [-sin(psi), cos(psi)]])
    
    gamma = sqrt(alpha**2 + beta**2)
    x = cos(gamma)
    y = beta*sin(gamma)/gamma
    z = alpha*sin(gamma)/gamma
    M_xyz = matrix([[ x - y*1j, z     ],\
                    [-z       , x+y*1j]])
    
    M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
    
    W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                       [      0        , exp(1j*delta)]])
    M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
    
    M[g] = R_global.transpose()*M_LCDp*R_global
    print(res.x)
# Out:
# [  2.41713257e+00   2.54768610e-17]
# [  2.34912688e+00   3.07342380e-16]
# [  2.27344428e+00   2.03104856e-18]
# [ 2.1574613   0.01835927]
# [ 2.02729987  0.04210887]
# [ 1.89800491  0.06483183]
# [ 1.77235181  0.08544711]
# [ 1.65013751  0.10494354]
# [ 1.52173465  0.12406649]
# [ 1.40990274  0.1394403 ]
# [ 1.28791217  0.15404632]
# [ 1.1820859   0.16514351]
# [ 1.07157653  0.17603997]
# [ 0.97183813  0.18378628]
# [ 0.88167431  0.18913085]
# [ 0.79601383  0.19205656]
# [ 0.71023095  0.19338878]
# [ 0.63806559  0.19257177]
# [ 0.56816519  0.18902797]
# [ 0.50233006  0.18424988]
# [ 0.44357774  0.17629317]
# [ 0.39247671  0.1660439 ]
# [ 0.34473565  0.15321673]
# [ 0.29645834  0.13764002]
# [ 0.25487547  0.11941679]
# [ 0.21570524  0.09305873]
# [ 0.17982832  0.05907743]
# [ 0.14540471  0.01864107]
# [  1.19039467e-01  -3.46944695e-18]
# [  9.94112213e-02  -2.83685460e-18]
# [  8.25352736e-02  -2.83685460e-18]
# [  6.66098784e-02  -1.60597714e-18]
# [  5.13158545e-02  -1.60597714e-18]
# [  3.96182440e-02  -4.06337442e-19]
# [  2.81886094e-02   7.81632902e-19]
# [  1.71789671e-02   1.93820726e-19]
# [  8.02674570e-03   1.93820726e-19]
# [ -2.58255617e-04   8.77219832e-01]
# [ -8.32837744e-05   9.17967021e-01]
# [ -3.93418025e-04   9.44240582e-01]
# [ -1.16394837e-04   9.67211493e-01]
# [  5.21399784e-05   9.81493383e-01]
# [ -4.11807191e-04   9.89459515e-01]
# [ -3.21817801e-04   1.00097852e+00]
# [ -1.74533824e-04   1.00735814e+00]
# [ -9.38425858e-06   1.01416968e+00]
# [ -2.26016866e-04   1.01789880e+00]
# [ -8.57480775e-05   1.02034090e+00]
# [-0.0016014   1.01634691]
# [-0.01677114  0.94543805]
# [-0.03168716  0.87961473]
# [-0.04324851  0.82745529]

# %% [markdown]
# Figura que compara las intensidades normalizadas experimentales en verde con las intensidades
# normalizadas producidas por los vectores de Jones definidos antes entrando y saliendo de la matriz
# que resulta de la caracterización.

# %%
#%pylab inline 

fig = figure()
gs1 = gridspec.GridSpec(8, 6)
axes = []
for i in range(8):
    for j in range(6):
        #if i+j!=6:
        axes.append(fig.add_subplot(gs1[i,j]))
        
for i in range(1,40,2):
    In1, Out1 = brakets[i]
    In2, Out2 = brakets[i+1]
    
    I_test1 = zeros(52)
    I_test2 = zeros(52)
    
    for g in range(52):
        I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        
    n = '8'+str(g)
    axes[i-1].plot(I_test1, label = 'It')
    axes[i-1].plot(I_exp[i], label = 'Ie')
    axes[i-1].set_title('$I_{'+str(i)+'}$')
    axes[i-1].set_ylim(0, 1)
    axes[i].set_ylim(0, 1)
    axes[i].plot(I_test2, label = 'It')
    axes[i].plot(I_exp[i+1], label = 'Ie')
    axes[i].set_title('$I_{'+str(i+1)+'}$')
show()

# %%
def min_all(x0,I_exp,g,brakets):
    min_of_functions = 0
    beta,delta = pi, 0
    M = {}
    bnds = ((0, 2*pi), (0, pi/4))   
    alpha,psi = x0
    for g in range(51,-1,-1):   
        #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
        res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP', bounds = bnds)
        #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')        
        #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
        #res = fmin_l_bfgs_b(min_sq,[ 2.6,  0],fprime=None,approx_grad=1, args = (I_exp,g,alpha,psi,brakets),pgtol=1e-05)
        
        #alpha,beta,psi,delta = res[0]
        beta,delta = res.x
        
        R = matrix([[ cos(alpha), sin(alpha)],\
                    [-sin(alpha), cos(alpha)]])
        R_global = matrix([[ cos(psi), sin(psi)],\
                           [-sin(psi), cos(psi)]])
        
        gamma = sqrt(alpha**2 + beta**2)
        x = cos(gamma)
        y = beta*sin(gamma)/gamma
        z = alpha*sin(gamma)/gamma
        M_xyz = matrix([[ x - y*1j, z     ],\
                        [-z       , x+y*1j]])
        
        M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
        
        W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                           [      0        , exp(1j*delta)]])
        M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
        
        M[g] = R_global.transpose()*M_LCDp*R_global
        
        min_of_functions += res.fun
    print(alpha,psi)    
    print(min_of_functions)
    return min_of_functions

# %%
#result = minimize(min_all,[-pi/2,-pi/4], args = (I_exp,g,brakets),method = 'Nelder-Mead')

# %% [markdown]
# Extracción de los parámetros X, Y, Z, y W obtenidos por minimización:

# %%
for g in range(52):
     X[g] = M[g][0,0].real
     Y[g] = -M[g][0,0].imag
     Z[g] = M[g][0,1].real
     W[g] = -M[g][0,1].imag

# %% [markdown]
# Gráfica de X, Y, Z, y W

# %% [markdown]
# Figura que compara las intensidades experimentales en verde con las intensidades
# producidas por los vectores de Jones definidos antes entrando y saliendo de la matriz
# que resulta de la caracterización.

# %%
f = figure()
ax = f.gca()
plot(X,label='X,76,34')
plot(Y,label='Y,34,76')
plot(Z,label='Z, 34,57')
plot(W,label='W, 57,34')
grid()
# Shink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
legend(bbox_to_anchor=(1.01, 1), loc=2)
show()

# %%
bet = figure()
ax = f.gca()
plot(Beta, label = 'beta')
plot(Delta, label = 'delta')
grid()
show()

# %% [raw]
# fig = figure()
# gs1 = gridspec.GridSpec(8, 6)
# axes = []
# for i in range(8):
#     for j in range(6):
#         #if i+j!=6:
#         axes.append(fig.add_subplot(gs1[i,j]))
#
# for i in range(1,46,2):
#     In1, Out1 = brakets[i]
#     In2, Out2 = brakets[i+1]
#
#     I_test1 = zeros(52)
#     I_test2 = zeros(52)
#
#     for g in range(52):
#         I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real
#         I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real
#
#     n = '8'+str(g)
#     axes[i-1].plot(I_test1, label = 'It')
#     axes[i-1].plot(I_exp_2[i][:,1], label = 'Ie')
#     axes[i-1].set_title('$I_{'+str(i)+'}$')
#     axes[i-1].set_ylim(0, 1)
#     axes[i].plot(I_test2, label = 'It')
#     axes[i].plot(I_exp_2[i+1][:,1], label = 'Ie')
#     axes[i].set_title('$I_{'+str(i+1)+'}$')
#     axes[i].set_ylim(0, 1)

# %% [markdown]
# ## Búsqueda de una combinación de estados de polarización que generen modulación sólo de fase

# %% [markdown]
# Script para encontrar la fase vs nivel de gris introducida por la matriz de Jones del modulador. Estoy probando una forma alternativa en la cual no hago uso de la función "arctan" para obtener la fase introducida por la matriz de Jones antes de encontrar el parámetro beta.
# En vez de eso estoy extrayendo el ángulo del valor que se produce cuando el ket es multiplicado por la matriz M.

# %%
from numpy import arctan,arctan2, info

phi = zeros(52)

## Sección que sigue lo usado por I. Moreno, dónde a partir de una formula 
## y las variables X,Y,Z,w del modulador se extrae la fase.

#chi1 = 0#pi/4#0.3490658503988659#-0.43307956358421984#0.2181361052344816
#chi2 = 0#pi/4#0.3490658503988659#0.59291218452902072#0.63376524318875027
#for i in range(0,52):
#    phi[i] = arctan((Y[i]*cos(chi1+chi2)+W[i]*sin(chi1+chi2))/  \
#		            (X[i]*cos(chi1-chi2)+Z[i]*sin(chi1+chi2)))
fig1 = figure()   
for i in range(1,41):
    
    In, Out =brakets[i]
    
    for g in range(52):
        ket2 = Out.H*M[g]*In
        phi[g] = angle(ket2)
        if g>0 and phi[g]-phi[g-1]>pi:
               phi[g] =phi[g]-2*pi
        elif g>0 and phi[g]-phi[g-1] <- pi:
               phi[g] =phi[g]+2*pi
    
             
    phi = phi - phi[0]
    plot(phi,color = 'r')
    image = loadtxt("Imagen{0}_fase".format(i))
    #image = loadtxt('If1-52_fase')#"Im{0}_fase".format(i))
    plot(image[::,1],color = 'b')
    beta = image[::,1]-phi
    plot(beta,color = 'g')
show()

# %%
def measure_best_modulation(x0, Jones_matrix, beta, a, b):
    """ Function for finding a configuration where phase modulation 
    is maximum and intensity variation is a minimum
    
    x0: Are the variables that we will vary s a list that includes 
        the parameters for input and output of the braket.
        
    Jones_matrix: Is the matrix that we obtained by doing the 
                characterization of the SLM.
    
    beta: Is the global phase by gray level that the SLM introduces.
    
    a, b: Are weights used to give more or less priority to a state where 
          flatness of the intensity curve is prioritized or range of phase
          modulation is.
    """

    chi2,phi2,chi1,phi1 = x0
    from numpy import arctan2
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    
    In, Out =intensity([ chi2,   phi2],     [chi1,phi1])
    
    phi_t = zeros(52)
    I = zeros(52)
    cambio = 0
    for g in range(52):
        ket2 = Out.H*exp(1j*beta[g])*M[g]*In # Beta was negative.
        I[g] = (ket2.H*ket2)[0,0].real
        phi_t[g] = arctan2(ket2.imag,ket2.real)
    #plot(phi_t)
    for g in range(52):
        if g>0 and  phi_t[g] - phi_t[g-1] > pi-0.1:
            phi_t[g:] = phi_t[g:]-2*pi
        if g>0 and  phi_t[g] - phi_t[g-1] < -pi+0.1:
            phi_t[g:] = phi_t[g:]+2*pi
    
    phi_t = phi_t - phi_t[0]
    
    p = (max(I)-min(I))/average(I)
    q = max(phi_t)-min(phi_t)
    plot(phi_t)
    return p**a/q**b 

bnds = ((-pi/1, pi/1), (-pi, pi),(-pi/1, pi/1), (-pi/1, pi/1))
#bnds = ((-pi, pi),(-pi, pi), (-pi/2, pi/2))

from scipy.optimize import fmin_l_bfgs_b
res = fmin_l_bfgs_b(measure_best_modulation,[ pi/8,0,pi/8,0],\
                    fprime=None,approx_grad=1,  args = (M,beta,2,0), pgtol=1e-05,bounds =bnds)

#res = minimize(measure_modulation,[ .5,  0.5,  0.5, 0.5], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res[0]

res
# Out:
# (array([ 2.25873662, -1.74454139, -1.61360162, -0.47823235]),
#  0.019511530500967159,
#  {'funcalls': 81,
#   'grad': array([-0.29473701, -0.10050423, -0.16368738,  0.00184834]),
#   'nit': 21,
#   'task': b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH',
#   'warnflag': 0})

# %%
chi2,phi2,chi1,phi1 = res[0]
#chi2,phi2,chi1,phi1 = [pi/4,pi/2,0,0]
In, Out =intensity([ chi2, phi2],     [chi1,phi1])
print(In, Out)
phi1 = zeros(52)
phi2 = zeros(52)
phi_t = zeros(52)
I = zeros(52)
for g in range(52):
    #*exp(1j*-beta[g])
    ket2 = Out.H*exp(1j*beta[g])*M[g]*In
    #print(ket2)
    I[g] = (ket2.H*ket2)[0,0].real
    phi_t[g] = arctan2(ket2.imag,ket2.real)
#for g in range(52):
    #print('g',g,'phi_t[g] - phi_t[g-1]',phi_t[g] - phi_t[g-1])
    #print('phi_t[g]',phi_t[g],'phi_t[g-1]', phi_t[g-1])
    
    #if g>1 and  phi_t[g] - phi_t[g-1] > pi:
    #    phi_t[g:] = phi_t[g:]-2*pi
    #if g>1 and  phi_t[g] - phi_t[g-1] < -pi:
    #    phi_t[g:] = phi_t[g:]+2*pi
figure()
phi_t = phi_t - phi_t[0]
plot(phi_t)
figure()
plot(I)
abs(max(phi_t)-min(phi_t))
# Out:
# [[-0.04279222+0.j        ]
#  [-0.88699656+0.45978901j]] [[-0.63494729+0.j        ]
#  [-0.13355338-0.76092406j]]
# 6.1729440900874621

# %%
phi_t
# Out:
# array([  0.00000000e+00,  -1.25839588e-03,  -2.40869588e-03,
#          8.41058373e-03,   1.38605912e-02,   1.61661653e-02,
#          4.25746956e-02,   3.63586688e-02,   6.87091603e-02,
#          6.24617217e-02,   6.34279944e-02,   3.56113903e-02,
#          2.02750467e-02,   4.19445620e-02,   2.64676253e-02,
#          2.35443294e-02,   1.75751181e-02,   7.85077650e-03,
#          1.93434690e-02,   7.83561214e-04,   2.34564222e-03,
#         -2.66077088e-02,  -6.16485419e-02,  -7.14882012e-02,
#         -6.88281679e-02,  -8.64581206e-02,  -1.24504311e-01,
#         -1.63517968e-01,  -1.66023848e-01,  -2.30965483e-01,
#         -2.30541636e-01,  -2.26835852e-01,  -3.66498759e-01,
#         -4.21596890e-01,  -4.64746237e-01,  -5.31206113e-01,
#         -6.36272894e-01,  -7.55329344e-01,  -8.52945067e-01,
#         -9.71780811e-01,  -1.10483259e+00,  -1.19789900e+00,
#         -1.36211012e+00,   4.81083397e+00,   4.72548797e+00,
#          4.50262230e+00,   4.33070167e+00,   4.19383387e+00,
#          3.87337410e+00,   3.71558278e+00,   3.62423195e+00,
#          3.54972972e+00])

# %%
plot(phi_t)

# %%
phi_t[-5]-phi_t[-6]
# Out:
# -0.13686780627940021

# %%
deg2rad(20)
# Out:
# 0.3490658503988659

# %%
plot(phi_t[::-1])

# %% [raw]
# La función que esta comentntado debajo hace un barrido dobre muchos estados de entrada y salida hasta llegar a una combinación que sea relativamente buena. Lo comenté porque no es muy bueno.

# %% [raw]
# def get_optimal_state(Jones_matrix):
#     """ Function for finding a configuration where the amplitude
#     is not modulated"""
#     def intensity(bra,ket):
#         In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
#         Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
#         return In, Out
#
#     optimal = {'chi1':0,'chi2':0,'theta1':0,'theta2':0,'value':0 }
#     for chi1 in linspace(0,pi,20):
#         for chi2 in linspace(0,pi,20):
#             for theta1 in linspace(0,pi,10):
#                 for theta2 in linspace(0,pi,10):
#                     I_sim = zeros(52)
#                     for g in range(52):
#                         In,Out = intensity([chi2,theta2],[chi1,theta1])
#                         I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
#                     p = (max(I_sim)-min(I_sim))/average(I_sim)
#                     if 1/p >  optimal['value']:
#                         optimal = {'chi1':chi1,'chi2':chi2,'theta1':theta1,'theta2':theta2,'value':p }
#     return optimal
# optimal = get_optimal_state(M)

# %% [markdown]
# Función que sólo optimiza para que la intensidad

# %%
def measure_flatness(x0,Jones_matrix):
    """ Function for finding a configuration where the amplitude
    is not modulated"""
    chi2,phi2,chi1,phi1 = x0
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    I_sim = zeros(52)
    for g in range(52):
        In,Out = intensity([chi2,phi2],[chi1,phi1])
        I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
    return  (max(I_sim)-min(I_sim))/average(I_sim)

bnds = ((-pi/1, pi/1), (-pi/2, pi/2),(-pi/1, pi/1), (-pi/1, pi/1))
res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res.x
res
# Out:
#      jac: array([-0.80972211,  0.25330101,  0.94443463,  0.03588593,  0.        ])
#     njev: 15
#      fun: 0.48112070287448255
#   status: 0
#        x: array([ 0.67375903, -0.85694722,  0.05583169,  0.31679576])
#  success: True
#      nit: 15
#  message: 'Optimization terminated successfully.'
#     nfev: 144

# %%
I_sim = zeros(52)
for g in range(52):
    In,Out = intensity([chi2,phi2],[chi1,phi1])
    I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
figure()
plot(I_sim)
ylim((0,1))
# Out:
# (0, 1)

# %%
from numpy import arctan, info
phi = zeros(52)
#chi1 = -0.43307956358421984#0.2181361052344816
#chi2 = 0.59291218452902072#0.63376524318875027
for i in range(0,52):
    phi[i] = arctan((Y[i]*cos(chi1+chi2)+W[i]*sin(chi1+chi2))/\
		            X[i]*cos(chi1-chi2)+Z[i]*sin(chi1+chi2))
figure()
plot(phi)
max(phi)-min(phi)
# Out:
# 3.0068470737533266

# %%
def measure_modulation(x0,Jones_matrix):
    """ Function for finding a configuration where phase modulation 
    is maximum"""
    chi2,phi2,chi1,phi1 = x0
    
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    
    In, Out =intensity([ chi2,   phi2],     [chi1,phi1])
    
    phi_t = zeros(52)
    I = zeros(52)
    for g in range(52):
        ket2 = Out.H*exp(1j*-beta[g])*M[g]*In
        I[g] = (ket2.H*ket2)[0,0].real
        phi_t[g] = (angle(ket2))
        if g>0 and phi_t[g]-phi_t[g-1]>pi:
           phi_t[g] =phi_t[g]-2*pi
        elif g>0 and phi_t[g]-phi_t[g-1] <- pi:
           phi_t[g] =phi_t[g]+2*pi
    print(max(phi_t)-min(phi_t))
    print(1/(max(phi_t)-min(phi_t)))
    return  1/(max(phi_t)-min(phi_t))

bnds = ((-pi/1, pi/1), (-pi, pi),(-pi/1, pi/1), (-pi/1, pi/1))
#bnds = ((-pi, pi),(-pi, pi), (-pi/2, pi/2))

from scipy.optimize import fmin_l_bfgs_b
res = fmin_l_bfgs_b(measure_modulation,[ .5,  0.5,  0.5, 0.5],fprime=None,approx_grad=1,  args = (M,), pgtol=1e-05,bounds =bnds)

#res = minimize(measure_modulation,[ .5,  0.5,  0.5, 0.5], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res[0]

res
# Out:
# 4.60006606463
# 0.217388182246
# 4.60006606463
# 0.217388182246
# 4.60006604997
# 0.217388182938
# 4.60006607563
# 0.217388181726
# 4.60006609431
# 0.217388180843
# 4.60006606751
# 0.21738818211
# 5.23564356225
# 0.190998487217
# 5.23564356225
# 0.190998487217
# 5.23564353441
# 0.190998488233
# 5.23564356633
# 0.190998487069
# 5.23564359106
# 0.190998486166
# 5.23564355573
# 0.190998487455
# 2.9746845483
# 0.336170099304
# 2.9746845483
# 0.336170099304
# 2.97468454886
# 0.33617009924
# 2.97468454075
# 0.336170100158
# 2.97468454695
# 0.336170099457
# 2.97468454467
# 0.336170099715
# 5.90862140707
# 0.169244216393
# 5.90862140707
# 0.169244216393
# 5.90862138652
# 0.169244216981
# 5.90862140429
# 0.169244216472
# 5.90862141745
# 0.169244216095
# 5.90862139531
# 0.169244216729
# 6.21875363489
# 0.16080392611
# 6.21875363489
# 0.16080392611
# 6.21875362081
# 0.160803926474
# 6.21875363206
# 0.160803926183
# 6.21875363757
# 0.160803926041
# 6.2187536238
# 0.160803926397
# 1.4080799129
# 0.710186965127
# 1.4080799129
# 0.710186965127
# 1.40807997966
# 0.710186931458
# 1.40807991611
# 0.710186963508
# 1.40807994124
# 0.710186950832
# 1.40807995392
# 0.710186944439
# 6.22037949547
# 0.160761895754
# 6.22037949547
# 0.160761895754
# 6.22037948141
# 0.160761896117
# 6.22037949264
# 0.160761895827
# 6.22037949811
# 0.160761895686
# 6.22037948437
# 0.160761896041
# 1.97642808571
# 0.505963261315
# 1.97642808571
# 0.505963261315
# 1.9764281881
# 0.505963235103
# 1.97642809396
# 0.505963259202
# 1.97642810858
# 0.50596325546
# 1.9764281463
# 0.505963245803
# 6.22141836704
# 0.160735051238
# 6.22141836704
# 0.160735051238
# 6.221418353
# 0.160735051601
# 6.22141836421
# 0.160735051311
# 6.22141836966
# 0.16073505117
# 6.22141835595
# 0.160735051525
# 2.80357984301
# 0.356686827554
# 2.80357984301
# 0.356686827554
# 2.80358024351
# 0.356686776601
# 2.80357989018
# 0.356686821553
# 2.80357995831
# 0.356686812886
# 2.80358009365
# 0.356686795668
# 6.2231441085
# 0.160690477766
# 6.2231441085
# 0.160690477766
# 6.22314409448
# 0.160690478128
# 6.22314410568
# 0.160690477839
# 6.22314411109
# 0.160690477699
# 6.22314409741
# 0.160690478052
# 6.319422455
# 0.158242308869
# 6.319422455
# 0.158242308869
# 6.31942244221
# 0.15824230919
# 6.31942245261
# 0.158242308929
# 6.31942245582
# 0.158242308849
# 6.31942244416
# 0.158242309141
# 1.06131667115
# 0.942225847558
# 1.06131667115
# 0.942225847558
# 1.06131664348
# 0.942225872118
# 1.06131667449
# 0.942225844592
# 1.06131667721
# 0.942225842174
# 1.06131665911
# 0.942225858247
# 6.3214973186
# 0.158190370034
# 6.3214973186
# 0.158190370034
# 6.32149730583
# 0.158190370354
# 6.32149731623
# 0.158190370094
# 6.32149731939
# 0.158190370014
# 6.32149730777
# 0.158190370305
# 0.616940288939
# 1.62090240811
# 0.616940288939
# 1.62090240811
# 0.616940270314
# 1.62090245704
# 0.616940290726
# 1.62090240341
# 0.616940287542
# 1.62090241178
# 0.61694027688
# 1.62090243979
# 6.32203026873
# 0.158177034512
# 6.32203026873
# 0.158177034512
# 6.32203025595
# 0.158177034831
# 6.32203026635
# 0.158177034571
# 6.32203026951
# 0.158177034492
# 6.32203025789
# 0.158177034783
# 0.905692621784
# 1.10412735618
# 0.905692621784
# 1.10412735618
# 0.905692668204
# 1.10412729959
# 0.905692621445
# 1.10412735659
# 0.905692642594
# 1.10412733081
# 0.905692648951
# 1.10412732306
# 6.32293704678
# 0.158154350202
# 6.32293704678
# 0.158154350202
# 6.32293703401
# 0.158154350521
# 6.32293704441
# 0.158154350261
# 6.32293704755
# 0.158154350183
# 6.32293703594
# 0.158154350473
# 1.32249305199
# 0.756147639867
# 1.32249305199
# 0.756147639867
# 1.32249312521
# 0.756147598001
# 1.32249305457
# 0.75614763839
# 1.32249306592
# 0.756147631902
# 1.32249309265
# 0.756147616618
# 6.32347032604
# 0.15814101252
# 6.32347032604
# 0.15814101252
# 6.32347031328
# 0.158141012839
# 6.32347032368
# 0.158141012579
# 6.3234703268
# 0.158141012501
# 6.3234703152
# 0.158141012791
# 1.70917439062
# 0.585077804517
# 1.70917439062
# 0.585077804517
# 1.70917448675
# 0.58507777161
# 1.70917439696
# 0.585077802346
# 1.70917441212
# 0.585077797156
# 1.70917444664
# 0.58507778534
# 6.32375336244
# 0.158133934498
# 6.32375336244
# 0.158133934498
# 6.32375334967
# 0.158133934818
# 6.32375336007
# 0.158133934558
# 6.32375336319
# 0.15813393448
# 6.3237533516
# 0.158133934769
# 2.03526819924
# 0.491335736672
# 2.03526819924
# 0.491335736672
# 2.0352683415
# 0.491335702329
# 2.03526820991
# 0.491335734096
# 2.03526821874
# 0.491335731965
# 2.03526828051
# 0.491335717053
# 6.32390522056
# 0.158130137174
# 6.32390522056
# 0.158130137174
# 6.3239052078
# 0.158130137493
# 6.3239052182
# 0.158130137233
# 6.32390522131
# 0.158130137155
# 6.32390520973
# 0.158130137445
# 2.34155110233
# 0.427067339682
# 2.34155110233
# 0.427067339682
# 2.34155124227
# 0.427067314157
# 2.34155111652
# 0.427067337093
# 2.34155113635
# 0.427067333476
# 2.34155118746
# 0.427067324154
# 6.32397866721
# 0.158128300651
# 6.32397866721
# 0.158128300651
# 6.32397865445
# 0.15812830097
# 6.32397866485
# 0.15812830071
# 6.32397866796
# 0.158128300632
# 6.32397865637
# 0.158128300922
# 2.69367268333
# 0.371240353807
# 2.69367268333
# 0.371240353807
# 2.69367309907
# 0.37124029651
# 2.69367273986
# 0.371240346016
# 2.69367285711
# 0.371240329857
# 2.69367295816
# 0.371240315931
# 6.32402487735
# 0.158127145196
# 6.32402487735
# 0.158127145196
# 6.32402486459
# 0.158127145515
# 6.32402487499
# 0.158127145255
# 6.3240248781
# 0.158127145177
# 6.32402486651
# 0.158127145466
# 6.35177244145
# 0.157436370591
# 6.35177244145
# 0.157436370591
# 6.35177242885
# 0.157436370903
# 6.35177243925
# 0.157436370645
# 6.35177244175
# 0.157436370583
# 6.35177243064
# 0.157436370859
# 2.83382811566
# 0.352879553447
# 2.83382811566
# 0.352879553447
# 2.83382858984
# 0.352879494401
# 2.83382817561
# 0.352879545981
# 2.83382827568
# 0.352879533521
# 2.83382841921
# 0.352879515648
# 6.35177442463
# 0.157436321435
# 6.35177442463
# 0.157436321435
# 6.35177441203
# 0.157436321747
# 6.35177442244
# 0.15743632149
# 6.35177442494
# 0.157436321428
# 6.35177441383
# 0.157436321703
# 2.93880967128
# 0.340273822348
# 2.93880967128
# 0.340273822348
# 2.93881019698
# 0.340273761479
# 2.93880973252
# 0.340273815257
# 2.93880980886
# 0.340273806418
# 2.93880999722
# 0.340273784608
# 2.28892230058
# 0.436886826497
# 2.28892230058
# 0.436886826497
# 2.28892243476
# 0.436886800886
# 2.28892231562
# 0.436886823627
# 2.28892234057
# 0.436886818864
# 2.2889223861
# 0.436886810174
# 6.31951348281
# 0.158240029509
# 6.31951348281
# 0.158240029509
# 6.31951347003
# 0.158240029829
# 6.31951348043
# 0.158240029568
# 6.31951348364
# 0.158240029488
# 6.31951347197
# 0.15824002978
# 2.65055109406
# 0.377280031402
# 2.65055109406
# 0.377280031402
# 2.65055131049
# 0.377280000596
# 2.65055111671
# 0.377280028178
# 2.65055113419
# 0.377280025691
# 2.65055122515
# 0.377280012743
# 6.31956377885
# 0.158238770111
# 6.31956377885
# 0.158238770111
# 6.31956376606
# 0.158238770431
# 6.31956377646
# 0.15823877017
# 6.31956377967
# 0.15823877009
# 6.31956376801
# 0.158238770382
# 6.35064201837
# 0.157464394483
# 6.35064201837
# 0.157464394483
# 6.35064200583
# 0.157464394794
# 6.35064201615
# 0.157464394538
# 6.35064201873
# 0.157464394474
# 6.35064200751
# 0.157464394752
# 2.73028341308
# 0.366262343027
# 2.73028341308
# 0.366262343027
# 2.73028362614
# 0.366262314445
# 2.73028343645
# 0.366262339891
# 2.73028345703
# 0.36626233713
# 2.73028354348
# 0.366262325534
# 6.35064427335
# 0.157464338571
# 6.35064427335
# 0.157464338571
# 6.3506442608
# 0.157464338882
# 6.35064427112
# 0.157464338626
# 6.3506442737
# 0.157464338562
# 6.35064426248
# 0.15746433884
# 2.87937748007
# 0.347297291488
# 2.87937748007
# 0.347297291488
# 2.87937815417
# 0.347297210181
# 2.87937756891
# 0.347297280773
# 2.87937771151
# 0.347297263573
# 2.87937791892
# 0.347297238556
# 6.35064539561
# 0.157464310744
# 6.35064539561
# 0.157464310744
# 6.35064538307
# 0.157464311055
# 6.35064539339
# 0.157464310799
# 6.35064539597
# 0.157464310735
# 6.35064538475
# 0.157464311013
# 2.9973570174
# 0.333627257012
# 2.9973570174
# 0.333627257012
# 2.99735778785
# 0.333627171255
# 2.99735710451
# 0.333627247315
# 2.99735718351
# 0.333627238522
# 2.99735749095
# 0.333627204302
# 6.35064591222
# 0.157464297935
# 6.35064591222
# 0.157464297935
# 6.35064589967
# 0.157464298246
# 6.35064590999
# 0.15746429799
# 6.35064591258
# 0.157464297926
# 6.35064590135
# 0.157464298204
# 6.35203819793
# 0.15742978377
# 6.35203819793
# 0.15742978377
# 6.3520381854
# 0.157429784081
# 6.35203819572
# 0.157429783825
# 6.35203819827
# 0.157429783762
# 6.35203818707
# 0.157429784039
# 6.35203819793
# 0.15742978377
# 6.35203819793
# 0.15742978377
# 6.3520381854
# 0.157429784081
# 6.35203819572
# 0.157429783825
# 6.35203819827
# 0.157429783762
# 6.35203818707
# 0.157429784039
# 2.16211777826
# 0.462509494189
# 2.16211777826
# 0.462509494189
# 2.16211776446
# 0.46250949714
# 2.1621177808
# 0.462509493645
# 2.16211779471
# 0.46250949067
# 2.1621177771
# 0.462509494437
# 2.11458045493
# 0.47290704767
# 2.11458045493
# 0.47290704767
# 2.11458058099
# 0.472907019477
# 2.11458046944
# 0.472907044425
# 2.11458050074
# 0.472907037423
# 2.11458053758
# 0.472907029184
# 6.35208173447
# 0.157428704762
# 6.35208173447
# 0.157428704762
# 6.35208172194
# 0.157428705073
# 6.35208173226
# 0.157428704817
# 6.35208173481
# 0.157428704754
# 6.35208172361
# 0.157428705031
# 2.32280253493
# 0.430514425984
# 2.32280253493
# 0.430514425984
# 2.32280275135
# 0.430514385872
# 2.32280255372
# 0.430514422502
# 2.32280255833
# 0.430514421648
# 2.32280266103
# 0.430514402612
# 6.35210358973
# 0.157428163107
# 6.35210358973
# 0.157428163107
# 6.3521035772
# 0.157428163418
# 6.35210358752
# 0.157428163162
# 6.35210359007
# 0.157428163099
# 6.35210357887
# 0.157428163377
# 2.50514055107
# 0.399179199575
# 2.50514055107
# 0.399179199575
# 2.50514076673
# 0.399179165212
# 2.50514057219
# 0.399179196209
# 2.50514058549
# 0.399179194091
# 2.50514068004
# 0.399179179025
# 6.35211384719
# 0.157427908891
# 6.35211384719
# 0.157427908891
# 6.35211383466
# 0.157427909202
# 6.35211384497
# 0.157427908946
# 6.35211384753
# 0.157427908883
# 6.35211383632
# 0.15742790916
# 2.62646291151
# 0.380740194585
# 2.62646291151
# 0.380740194585
# 2.62646312535
# 0.380740163587
# 2.62646293393
# 0.380740191335
# 2.62646295183
# 0.38074018874
# 2.62646304125
# 0.380740175778
# 6.35211854297
# 0.157427792513
# 6.35211854297
# 0.157427792513
# 6.35211853044
# 0.157427792823
# 6.35211854076
# 0.157427792568
# 6.35211854331
# 0.157427792504
# 6.35211853211
# 0.157427792782
# 2.70652399907
# 0.369477603134
# 2.70652399907
# 0.369477603134
# 2.70652421126
# 0.369477574167
# 2.70652402221
# 0.369477599974
# 2.70652404252
# 0.369477597203
# 2.70652412885
# 0.369477585417
# 6.35212065704
# 0.157427740119
# 6.35212065704
# 0.157427740119
# 6.35212064451
# 0.157427740429
# 6.35212065482
# 0.157427740174
# 6.35212065738
# 0.157427740111
# 6.35212064617
# 0.157427740388
# 2.79129825789
# 0.35825623334
# 2.79129825789
# 0.35825623334
# 2.79129891185
# 0.358256149406
# 2.7912983553
# 0.358256220837
# 2.79129855799
# 0.358256194823
# 2.7912987052
# 0.358256175929
# 6.35212167122
# 0.157427714984
# 6.35212167122
# 0.157427714984
# 6.35212165869
# 0.157427715295
# 6.35212166901
# 0.157427715039
# 6.35212167156
# 0.157427714976
# 6.35212166035
# 0.157427715253
# 2.91329168744
# 0.343254334714
# 2.91329168744
# 0.343254334714
# 2.91329243143
# 0.343254247055
# 2.91329178183
# 0.343254323593
# 2.91329191688
# 0.34325430768
# 2.91329216443
# 0.343254278514
# 6.35212213778
# 0.157427703421
# 6.35212213778
# 0.157427703421
# 6.35212212525
# 0.157427703731
# 6.35212213557
# 0.157427703476
# 6.35212213812
# 0.157427703413
# 6.35212212692
# 0.15742770369
# 2.99878863768
# 0.333467983517
# 2.99878863768
# 0.333467983517
# 2.99878944102
# 0.333467894184
# 2.99878872837
# 0.333467973432
# 2.99878880958
# 0.333467964402
# 2.99878913111
# 0.333467928647
# 6.35212234867
# 0.157427698194
# 6.35212234867
# 0.157427698194
# 6.35212233614
# 0.157427698505
# 6.35212234646
# 0.157427698249
# 6.35212234901
# 0.157427698186
# 6.3521223378
# 0.157427698464
# 6.35212255953
# 0.157427692969
# 6.35212255953
# 0.157427692969
# 6.35212254699
# 0.157427693279
# 6.35212255731
# 0.157427693023
# 6.35212255986
# 0.15742769296
# 6.35212254866
# 0.157427693238
# 3.08504736435
# 0.324144131969
# 3.08504736435
# 0.324144131969
# 3.08504822262
# 0.324144041791
# 3.08504745004
# 0.324144122966
# 3.08504747292
# 0.324144120561
# 3.08504787012
# 0.324144078828
# 6.35212261421
# 0.157427691613
# 6.35212261421
# 0.157427691613
# 6.35212260167
# 0.157427691924
# 6.35212261199
# 0.157427691668
# 6.35212261454
# 0.157427691605
# 6.35212260334
# 0.157427691883
# 2.00728864385
# 0.498184455466
# 2.00728864385
# 0.498184455466
# 2.00728877006
# 0.498184424142
# 2.00728865597
# 0.498184452458
# 2.00728867763
# 0.498184447083
# 2.00728872294
# 0.498184435836
# 6.35210659029
# 0.157428088743
# 6.35210659029
# 0.157428088743
# 6.35210657775
# 0.157428089054
# 6.35210658807
# 0.157428088798
# 6.35210659062
# 0.157428088735
# 6.35210657942
# 0.157428089012
# 2.21920607266
# 0.450611600392
# 2.21920607266
# 0.450611600392
# 2.21920620441
# 0.450611573639
# 2.21920608712
# 0.450611597455
# 2.21920611246
# 0.45061159231
# 2.21920615673
# 0.450611583321
# 6.35213924556
# 0.157427279432
# 6.35213924556
# 0.157427279432
# 6.35213923303
# 0.157427279742
# 6.35213924335
# 0.157427279487
# 6.3521392459
# 0.157427279423
# 6.35213923469
# 0.157427279701
# 2.41117977605
# 0.414734732736
# 2.41117977605
# 0.414734732736
# 2.41118000189
# 0.41473469389
# 2.41117979575
# 0.414734729348
# 2.41117979874
# 0.414734728833
# 2.41117990711
# 0.414734710194
# 6.35215553921
# 0.157426875621
# 6.35215553921
# 0.157426875621
# 6.35215552668
# 0.157426875932
# 6.352155537
# 0.157426875676
# 6.35215553955
# 0.157426875613
# 6.35215552835
# 0.157426875891
# 2.56698635041
# 0.389561868858
# 2.56698635041
# 0.389561868858
# 2.56698656993
# 0.389561835545
# 2.56698637216
# 0.389561865557
# 2.56698638556
# 0.389561863523
# 2.5669864817
# 0.389561848934
# 6.35216308413
# 0.157426688634
# 6.35216308413
# 0.157426688634
# 6.3521630716
# 0.157426688945
# 6.35216308192
# 0.157426688689
# 6.35216308447
# 0.157426688626
# 6.35216307326
# 0.157426688904
# 2.66813067077
# 0.374794237387
# 2.66813067077
# 0.374794237387
# 2.66813088611
# 0.374794207137
# 2.66813069359
# 0.374794234181
# 2.66813071195
# 0.374794231603
# 2.66813080158
# 0.374794219012
# 6.35216650728
# 0.157426603798
# 6.35216650728
# 0.157426603798
# 6.35216649475
# 0.157426604109
# 6.35216650506
# 0.157426603853
# 6.35216650762
# 0.15742660379
# 6.35216649641
# 0.157426604067
# 2.82063727062
# 0.354529811548
# 2.82063727062
# 0.354529811548
# 2.8206379024
# 0.354529732139
# 2.82063736017
# 0.354529800293
# 2.82063753082
# 0.354529778844
# 2.82063769426
# 0.354529758301
# 6.35216748857
# 0.157426579478
# 6.35216748857
# 0.157426579478
# 6.35216747604
# 0.157426579789
# 6.35216748636
# 0.157426579533
# 6.35216748891
# 0.15742657947
# 6.35216747771
# 0.157426579748
# 2.99181960747
# 0.334244751088
# 2.99181960747
# 0.334244751088
# 2.99182037697
# 0.334244665121
# 2.99181969514
# 0.334244741294
# 2.99181977781
# 0.334244732058
# 2.9918200817
# 0.334244698108
# 6.35216772683
# 0.157426573574
# 6.35216772683
# 0.157426573574
# 6.3521677143
# 0.157426573884
# 6.35216772462
# 0.157426573628
# 6.35216772717
# 0.157426573565
# 6.35216771597
# 0.157426573843
# 3.0500802162
# 0.327860229605
# 3.0500802162
# 0.327860229605
# 3.05008103156
# 0.327860141961
# 3.05008030189
# 0.327860220395
# 3.05008034812
# 0.327860215425
# 3.05008070486
# 0.327860177078
# 6.3521678333
# 0.157426570935
# 6.3521678333
# 0.157426570935
# 6.35216782077
# 0.157426571246
# 6.35216783109
# 0.15742657099
# 6.35216783364
# 0.157426570927
# 6.35216782244
# 0.157426571204
# 3.09007252344
# 0.323617000059
# 3.09007252344
# 0.323617000059
# 3.09007336945
# 0.323616911458
# 3.09007260737
# 0.323616991269
# 3.09007262697
# 0.323616989216
# 3.09007302097
# 0.323616947953
# 6.35216788048
# 0.157426569766
# 6.35216788048
# 0.157426569766
# 6.35216786795
# 0.157426570076
# 6.35216787827
# 0.157426569821
# 6.35216788082
# 0.157426569757
# 6.35216786962
# 0.157426570035
# 3.11713243542
# 0.320807672025
# 3.11713243542
# 0.320807672025
# 3.11713330167
# 0.320807582873
# 3.11713251798
# 0.320807663527
# 3.1171325189
# 0.320807663433
# 3.11713293844
# 0.320807620255
# 6.35216790127
# 0.15742656925
# 6.35216790127
# 0.15742656925
# 6.35216788874
# 0.157426569561
# 6.35216789906
# 0.157426569305
# 6.35216790161
# 0.157426569242
# 6.35216789041
# 0.15742656952
# (array([ 0.13507986,  0.62909214,  0.94955729,  0.39924507]),
#  0.15742656925037776,
#  {'funcalls': 85,
#   'grad': array([ 0.03106491,  0.00549059, -0.00083675,  0.02693061]),
#   'nit': 5,
#   'task': b'ABNORMAL_TERMINATION_IN_LNSRCH',
#   'warnflag': 2})

# %%
def translate(psi,delta):
    psi = psi*180/pi
    delta = delta*180/pi
    return psi, delta
translate(-1.72185039, -1.57079632679)
# Out:
# (-98.6547602999548, -89.99999999971946)

# %%
translate(2.09922953, 1.44670384974)
# Out:
# (120.27699229823145, 82.8900247954304)

# %%
[ 2.25873662, -1.74454139, -1.61360162, -0.47823235]
# Out:
# [2.25873662, -1.74454139, -1.61360162, -0.47823235]

# %%
translate(2.25873662, 1.57079632679)
# Out:
# (129.41607535764481, 89.99999999971946)

# %%
translate(-1.61360162,-1.57079632679)
# Out:
# (-92.45256264147245, -89.99999999971946)
