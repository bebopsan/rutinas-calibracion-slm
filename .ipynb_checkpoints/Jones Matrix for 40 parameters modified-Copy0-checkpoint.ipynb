# %% [markdown]
# # Scripts para la construcción de la matriz de Jones usando las medidas experimentales

# %% [markdown]
# Importación de librerias y carga de archivos.

# %%
from sympy import symbols, Matrix
from numpy import loadtxt, zeros, matrix, exp, pi, sqrt, sign, cos, sin
from scipy.optimize import minimize
import matplotlib.gridspec as gridspec
from pylab import *
# %pylab inline

I_exp = {}
I = {}
for i in range(1,41):
   # image = "Imagen{0}_amp".format(i)
    image = "Imagen{0}_amp".format(i)
    I_exp[i] = loadtxt(image)    
    I[i] = zeros(52)
    
#I_exp[41] =  loadtxt("In21_amp")
#I[41] = zeros(52)
#I_exp[42] =  loadtxt("In22_amp")
#I[42] = zeros(52)
I_exp_2 = I_exp
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['linalg', 'power', 'fft', 'draw_if_interactive', 'info', 'random']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# ## Normalización

# %% [markdown]
# En este punto suceden dos cosas, primero realizo una normalización por pares.
# Asumiendo que cada medida esta antecedida por su estado ortogonal, lo que hago es:
# $$I_i = \frac{I_i^{exp}}{I_i^{exp}+I_{i+1}^{exp}}$$

# %%
# Averaging of intensities
for i in range(1,40,2):
    for g in range(I_exp[i].shape[0]):
        I[i][g] = I_exp[i][g,1]/(I_exp[i][g,1]+I_exp[i+1][g,1])
        I[i+1][g] = I_exp[i+1][g,1]/(I_exp[i][g,1]+I_exp[i+1][g,1])

# %% [markdown]
# Graficación de las curvas de indensidad normalizadas

# %%
fig = figure()
for i in range(1,41):
    plot(I[i],label='I{0}'.format(i))
plot(I[5]+I[6],label='I{0}'.format(i))

show()

# %% [markdown]
# Estas son las curvas equivalentes a las curvas de intensidad que se usan para caracterizar el modulador en el artículo de Moreno.

# %%
#fig = figure()
#plot(I[1],label='I1')
#plot(I[2],label='I2')
#plot(I[4],label='I3')
#plot(I[42],label='I4')
#plot(I[21],label='I5')
#plot(I[22],label='I6')
#plot(I[5],label='I7')
#plot(I[6],label='I7p')
#legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#display(fig)

# %% [markdown]
# ## Definición de X, Y, Z y W

# %% [markdown]
# Siguiendo las fórmulas que se exponen en el artículo de Moreno y Velazques
# encuentro los valores de X, Y, Z, y W, y sus signos.

# %%
X = zeros(52)
Y = zeros(52)
Z = zeros(52)
W = zeros(52)
#for i in range(3,43,2):
#    delta = I[i][0]-I[i+1][0]
#   I[i] = I[i]- delta/2
#    I[i+1] = I[i+1] + delta/2
#for g in range(I[1].shape[0]):
#    X[g] = sqrt( I[1][g]/(1+( (I[5][g]-I[22][g])/(I[4][g]-I[42][g]) )**2) )
#    Y[g] = sqrt( I[1][g]/(1+( (I[4][g]-I[42][g])/(I[5][g]-I[22][g]) )**2) )
#    Z[g] = sqrt( I[2][g]/(1+( (I[4][g]-I[42][g])/(I[21][g]-I[5][g]) )**2) )
#    W[g] = sqrt( I[2][g]/(1+( (I[21][g]-I[5][g])/(I[4][g]-I[42][g]) )**2) )
    
#    sign_Z = sign(I[21][g]-I[5][g])/sign(X[g])
#    if sign(Z[g]) != sign_Z:
#        Z[g] = Z[g]*-1
#    sign_W = sign(I[4][g]-I[42][g])/sign(X[g])
#    if sign(W[g]) != sign_W:
#       W[g] = W[g]*-1
#    sign_Y = sign(I[5][g]-I[22][g])/sign(X[g])
#    if sign(Z[g]) != sign_Y:
#        Y[g] = Y[g]*-1

# %% [markdown]
# Graficas de X, Y, Z y W:

# %%
## figure()
## plot(X,label='X,76,34')
## plot(Y,label='Y,34,76')
## plot(Z,label='Z, 34,57')
## plot(W,label='W, 57,34')
## grid()
## legend()

# %% [markdown]
# ## Matriz de Jones del modulador

# %% [markdown]
# Definición de Brakets siguiendo la formulación de vectores de Jones.

# %%
I_exp = I
def intensity(bra,ket):
    In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
    Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
    return In, Out
brakets = {1:intensity([ 0,   0],     [0,0]),\
           2:intensity([ pi/2,0],     [0,0]),\
           3:intensity([ pi/4,pi/2],  [0,0]),\
           4:intensity([ pi/4,-pi/2],  [0,0]),\
           5:intensity([ pi/4, 0],    [0,0]),\
           6:intensity([-pi/4, 0],    [0,0]),\
           7:intensity([ 3*pi/8, pi/2],  [0,0]),\
           8:intensity([pi/8,-pi/2],[0,0]),\
           9:intensity([ pi/4, pi/4],   [0,0]),\
           10:intensity([3*pi/4, pi/4],[0,0]),\
           11:intensity([ 0,   0],     [pi/2,0]),\
           12:intensity([ pi/2,0],     [pi/2,0]),\
           13:intensity([ pi/4,pi/2],  [pi/2,0]),\
           14:intensity([ pi/4,-pi/2],  [pi/2,0]),\
           15:intensity([ pi/4, 0],    [pi/2,0]),\
           16:intensity([-pi/4, 0],    [pi/2,0]),\
           17:intensity([ 3*pi/8, pi/2],  [pi/2,0]),\
           18:intensity([ pi/8, -pi/2],[pi/2,0]),\
           19:intensity([ pi/4, pi/4],   [pi/2,0]),\
           20:intensity([3*pi/4, pi/4],   [pi/2,0]),\
           21:intensity([ 0,   0],     [pi/4,0]),\
           22:intensity([ pi/2,0],     [pi/4,0]),\
           23:intensity([ pi/4,pi/2],  [pi/4,0]),\
           24:intensity([ pi/4,-pi/2],  [pi/4,0]),\
           25:intensity([ pi/4, 0],    [pi/4,0]),\
           26:intensity([-pi/4, 0],    [pi/4,0]),\
           27:intensity([3*pi/8, pi/2],  [pi/4,0]),\
           28:intensity([pi/8, -pi/2],[pi/4,0]),\
           29:intensity([pi/4, pi/4],   [pi/4,0]),\
           30:intensity([3*pi/4, pi/4],[pi/4,0]),\
           31:intensity([ 0,   0],     [-pi/4,0]),\
           32:intensity([ pi/2,0],     [-pi/4,0]),\
           33:intensity([ pi/4,pi/2],  [-pi/4,0]),\
           34:intensity([ pi/4,-pi/2],  [-pi/4,0]),\
           35:intensity([ pi/4, 0],    [-pi/4,0]),\
           36:intensity([-pi/4, 0],    [-pi/4,0]),\
           37:intensity([3*pi/8, pi/2],  [-pi/4,0]),\
           38:intensity([pi/8, -pi/2],[-pi/4,0]),\
           39:intensity([pi/4, pi/4],   [-pi/4,0]),\
           40:intensity([3*pi/4, pi/4],[-pi/4,0]),\
	       42:intensity([ 0,   0],     [pi/4,pi/2]),\
	       41:intensity([ pi/2,   0],     [pi/4,pi/2]),\
	       43:intensity([ pi/4, pi/2],     [pi/4,pi/2]),\
	       44:intensity([ pi/4, -pi/2],     [pi/4,pi/2]),\
	       45:intensity([ -pi/4, 0],     [pi/4,pi/2]),\
	       46:intensity([ pi/4, 0],     [pi/4,pi/2])}

# %% [markdown]
# Definición de una función a minimizar. Esta función calcula las diferencias cuadradas
# entre las medidas experimentales y las intensidades resultantes de operar con los
# vectores de Jones:

# %%
def min_sq(x0,I_exp,g,alpha,psi,brakets):
    """ Calculates squared differences for a minimization procedure.

    Given the experimental meassures of intensity and arbitrary values for 
    the parameters of an SLM Jones Matrix, this function gives a value to
    minimize. That value tells how close is the estimation of alpha, beta, psi, delta 
    to the value that correctly models the SLM.

    :param alpha,beta,psi,delta: Are a guess of real scalars that conform physical parameters the SLM.
    :param I_exp: Is a dictionary contanining intensities for every polarization state.
    :param g: Is the gray level of the SLM for which we are solving.
    """
    [beta, delta] = x0
    
    R = matrix([[ cos(alpha), sin(alpha)],\
                [-sin(alpha), cos(alpha)]])
    R_global = matrix([[ cos(psi), sin(psi)],\
                       [-sin(psi), cos(psi)]])
    
    gamma = sqrt(alpha**2 + beta**2)
    x = cos(gamma)
    y = beta*sin(gamma)/gamma
    z = alpha*sin(gamma)/gamma
    
    M_xyz = matrix([[ x - y*1j, z     ],\
                    [-z       , x+y*1j]])
    
    M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
    
    W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                       [      0        , exp(1j*delta)]])
    M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
    
    M = R_global.transpose()*M_LCDp*R_global
    
    min_sum = 0
    I_sim = {}
    for i in range(1,41):
        #if i%2 !=0:
	#if i in [1,2,5,6,11,12,15,16,21,22,25,26,31,32,36,35]:
        #if i in [1,2,3,4,5,6,11,12,15,16,21,22,25,26,31,33,35,36]:
        #if i in []:
        if i not in []:
            In, Out = brakets[i]
            I_sim[i] = (In.H*M.H*Out * Out.H*M*In)
            min_sum += ((I_sim[i]-I_exp[i][g])**2)[0,0].real
            #min_sum += (sqrt(abs(I_sim[i]**2-I_exp[i][g]**2)))[0,0].realqq
    
    return min_sum

# %% [markdown]
# Si probamos con unos valores iniciales cualquiera debe devolver un número escalar:

# %%
min_sq([2.6,0],I_exp,0,-pi/2,pi/4, brakets)
# Out:
# 11.362887461095129

# %% [markdown]
# Minimización con restricciónes de caja. El método que mejor hace la minimización es el SLSQP:

# %%
M = {}
bnds = ((0, 2*pi), (0, pi/4))
cons = ({'type': 'eq', 'fun': lambda x:  x[0]**2+x[1]**2+x[2]**2+x[3]**2 - 1})
from scipy.optimize import fmin_l_bfgs_b
beta,delta = 2.6, 0
alpha,psi = -1.63400317439, -0.627396281551
for g in range(51,-1,-1):   
    #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
    #res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'Nelder-Mead')
    res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP')
    #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')        
    #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
    #res = fmin_l_bfgs_b(min_sq,[ 2.6,  0],fprime=None,approx_grad=1, args = (I_exp,g,alpha,psi,brakets),pgtol=1e-05)
    
    #beta,delta = res[0]
    beta,delta = res.x
    R = matrix([[ cos(alpha), sin(alpha)],\
                [-sin(alpha), cos(alpha)]])
    R_global = matrix([[ cos(psi), sin(psi)],\
                       [-sin(psi), cos(psi)]])
    
    gamma = sqrt(alpha**2 + beta**2)
    x = cos(gamma)
    y = beta*sin(gamma)/gamma
    z = alpha*sin(gamma)/gamma
    M_xyz = matrix([[ x - y*1j, z     ],\
                    [-z       , x+y*1j]])
    
    M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
    
    W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                       [      0        , exp(1j*delta)]])
    M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
    
    M[g] = R_global.transpose()*M_LCDp*R_global
    print(res.x)
# Out:
# [ 2.52200386 -0.05285449]
# [ 2.40792348 -0.02979383]
# [ 2.28521679 -0.00602853]
# [ 2.15735822  0.01839469]
# [ 2.02722133  0.04216636]
# [ 1.89801658  0.0649067 ]
# [ 1.77204622  0.08569145]
# [ 1.64981991  0.1050433 ]
# [ 1.52149469  0.12412019]
# [ 1.40980143  0.13945091]
# [ 1.28781081  0.15410265]
# [ 1.18212542  0.16522193]
# [ 1.07168113  0.17580113]
# [ 0.97184503  0.1837786 ]
# [ 0.88167429  0.18913105]
# [ 0.79601383  0.19205656]
# [ 0.71023095  0.19338878]
# [ 0.6380656   0.19257176]
# [ 0.56816518  0.18902798]
# [ 0.50233006  0.18424988]
# [ 0.44357774  0.17629318]
# [ 0.39247671  0.1660439 ]
# [ 0.34473564  0.15321674]
# [ 0.29645833  0.13764001]
# [ 0.25487546  0.11941679]
# [ 0.21570524  0.09305875]
# [ 0.1798283   0.05907738]
# [ 0.14540471  0.01864108]
# [ 0.11080324 -0.04214089]
# [ 0.0746532  -0.13496838]
# [ 0.02819271 -0.31101617]
# [ 0.00070432 -0.44795071]
# [  1.25826576e-05  -4.68653533e-01]
# [  8.20033801e-06  -4.91049458e-01]
# [  5.80995496e-06  -5.14500859e-01]
# [  1.04377295e-05  -5.51835174e-01]
# [  1.04866671e-05  -5.98010405e-01]
# [  1.24952967e-05  -6.65704795e-01]
# [  8.05526885e-06  -7.82943931e-01]
# [ -5.05384493e-04  -2.19584032e+00]
# [  2.23919165e-06  -2.17383713e+00]
# [ -1.72763334e-03  -2.17244775e+00]
# [  2.56786542e-06  -2.14943359e+00]
# [ -1.63851242e-03  -2.14909428e+00]
# [-0.00266917 -2.14882117]
# [-0.00378755 -2.14851653]
# [-0.00478496 -2.1482357 ]
# [-0.0052832  -2.14807386]
# [-0.00610548 -2.14787543]
# [-0.00682965 -2.14773245]
# [-0.00785635 -2.14756476]
# [-0.00785635 -2.14756476]

# %% [markdown]
# Figura que compara las intensidades normalizadas experimentales en verde con las intensidades
# normalizadas producidas por los vectores de Jones definidos antes entrando y saliendo de la matriz
# que resulta de la caracterización.

# %%
#%pylab inline 

fig = figure()
gs1 = gridspec.GridSpec(8, 6)
axes = []
for i in range(8):
    for j in range(6):
        #if i+j!=6:
        axes.append(fig.add_subplot(gs1[i,j]))
        
for i in range(1,40,2):
    In1, Out1 = brakets[i]
    In2, Out2 = brakets[i+1]
    
    I_test1 = zeros(52)
    I_test2 = zeros(52)
    
    for g in range(52):
        I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real/\
        ((In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real+(In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real)
        
    n = '8'+str(g)
    axes[i-1].plot(I_test1, label = 'It')
    axes[i-1].plot(I_exp[i], label = 'Ie')
    axes[i-1].set_title('$I_{'+str(i)+'}$')
    axes[i-1].set_ylim(0, 1)
    axes[i].set_ylim(0, 1)
    axes[i].plot(I_test2, label = 'It')
    axes[i].plot(I_exp[i+1], label = 'Ie')
    axes[i].set_title('$I_{'+str(i+1)+'}$')
show()

# %%
def min_all(x0,I_exp,g,brakets):
    min_of_functions = 0
    beta,delta = 2.6, 0
    M = {}
    bnds = ((0, 2*pi), (0, pi/4))   
    alpha,psi = x0
    for g in range(51,-1,-1):   
        #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
        res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP', bounds = bnds)
        #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')        
        #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
        #res = fmin_l_bfgs_b(min_sq,[ 2.6,  0],fprime=None,approx_grad=1, args = (I_exp,g,alpha,psi,brakets),pgtol=1e-05)
        
        #alpha,beta,psi,delta = res[0]
        beta,delta = res.x
        R = matrix([[ cos(alpha), sin(alpha)],\
                    [-sin(alpha), cos(alpha)]])
        R_global = matrix([[ cos(psi), sin(psi)],\
                           [-sin(psi), cos(psi)]])
        
        gamma = sqrt(alpha**2 + beta**2)
        x = cos(gamma)
        y = beta*sin(gamma)/gamma
        z = alpha*sin(gamma)/gamma
        M_xyz = matrix([[ x - y*1j, z     ],\
                        [-z       , x+y*1j]])
        
        M_LCD = exp(-1j*beta)*R.transpose()*M_xyz
        
        W_2delta = matrix([[ exp(-1j*delta),        0      ],\
                           [      0        , exp(1j*delta)]])
        M_LCDp = R.transpose()*W_2delta*R*M_LCD*W_2delta
        
        M[g] = R_global.transpose()*M_LCDp*R_global
        
        min_of_functions += res.fun
    print(alpha,psi)    
    print(min_of_functions)
    return min_of_functions

# %%
result = minimize(min_all,[-pi/2,-pi/4], args = (I_exp,g,brakets),method = 'Nelder-Mead')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-5d37dee269fa> in <module>()
# ----> 1 result = minimize(min_all,[-pi/2,-pi/4], args = (I_exp,g,brakets),method = 'Nelder-Mead')
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     364
#     365     if meth == 'nelder-mead':
# --> 366         return _minimize_neldermead(fun, x0, args, callback, **options)
#     367     elif meth == 'powell':
#     368         return _minimize_powell(fun, x0, args, callback, **options)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, return_all, **unknown_options)
#     447
#     448         sim[k + 1] = y
# --> 449         f = func(y)
#     450         fsim[k + 1] = f
#     451
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# <ipython-input-43-670021cc47a9> in min_all(x0, I_exp, g, brakets)
#       7     for g in range(51,-1,-1):
#       8         #res = minimize(min_sq,[ X[g],  Y[g],  Z[g], W[g]], args = (I_exp,g),method = 'SLSQP',bounds =bnds,constraints=cons)
# ----> 9         res = minimize(min_sq,[beta,delta], args = (I_exp,g,alpha,psi,brakets),method = 'SLSQP', bounds = bnds)
#      10         #res = minimize(min_sq,[beta], args = (I_exp,g,alpha,psi,delta,brakets),method = 'Nelder-Mead')
#      11         #res = minimize(min_sq,[ 0.9,  .5,  .5, .5], args = (I_exp,g),method = 'COBYLA',bounds =bnds, options={ 'disp': True})
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     386     elif meth == 'slsqp':
#     387         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 388                                constraints, **options)
#     389     elif meth == 'dogleg':
#     390         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, **unknown_options)
#     352
#     353             # Compute objective function
# --> 354             fx = func(x)
#     355             # Compute the constraints
#     356             if cons['eq']:
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# <ipython-input-8-f510cff14663> in min_sq(x0, I_exp, g, alpha, psi, brakets)
#      39         if i not in []:
#      40             In, Out = brakets[i]
# ---> 41             I_sim[i] = (In.H*M.H*Out * Out.H*M*In)
#      42             min_sum += ((I_sim[i]-I_exp[i][g])**2)[0,0].real
#      43             #min_sum += (sqrt(abs(I_sim[i]**2-I_exp[i][g]**2)))[0,0].realqq
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.3/lib/python3.3/site-packages/numpy/matrixlib/defmatrix.py in getH(self)
#     988         """
#     989         if issubclass(self.dtype.type, N.complexfloating):
# --> 990             return self.transpose().conjugate()
#     991         else:
#     992             return self.transpose()
#
# KeyboardInterrupt:
# -1.57079632679 -0.785398163397
# 16.6733267743

# %% [markdown]
# Extracción de los parámetros X, Y, Z, y W extraídos por la minimización:

# %%
for g in range(52):
     X[g] = M[g][0,0].real
     Y[g] = -M[g][0,0].imag
     Z[g] = M[g][0,1].real
     W[g] = -M[g][0,1].imag

# %% [markdown]
# Gráfica de X, Y, Z, y W

# %%
f = figure()
ax = f.gca()
plot(X,label='X,76,34')
plot(Y,label='Y,34,76')
plot(Z,label='Z, 34,57')
plot(W,label='W, 57,34')
grid()
# Shink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
legend(bbox_to_anchor=(1.01, 1), loc=2)
show()

# %% [markdown]
# Figura que compara las intensidades experimentales en verde con las intensidades
# producidas por los vectores de Jones definidos antes entrando y saliendo de la matriz
# que resulta de la caracterización.

# %% [raw]
# fig = figure()
# gs1 = gridspec.GridSpec(8, 6)
# axes = []
# for i in range(8):
#     for j in range(6):
#         #if i+j!=6:
#         axes.append(fig.add_subplot(gs1[i,j]))
#
# for i in range(1,46,2):
#     In1, Out1 = brakets[i]
#     In2, Out2 = brakets[i+1]
#
#     I_test1 = zeros(52)
#     I_test2 = zeros(52)
#
#     for g in range(52):
#         I_test1[g] = (In1.H*M[g].H*Out1 * Out1.H*M[g]*In1)[0,0].real
#         I_test2[g] = (In2.H*M[g].H*Out2 * Out2.H*M[g]*In2)[0,0].real
#
#     n = '8'+str(g)
#     axes[i-1].plot(I_test1, label = 'It')
#     axes[i-1].plot(I_exp_2[i][:,1], label = 'Ie')
#     axes[i-1].set_title('$I_{'+str(i)+'}$')
#     axes[i-1].set_ylim(0, 1)
#     axes[i].plot(I_test2, label = 'It')
#     axes[i].plot(I_exp_2[i+1][:,1], label = 'Ie')
#     axes[i].set_title('$I_{'+str(i+1)+'}$')
#     axes[i].set_ylim(0, 1)

# %% [markdown]
# ## Búsqueda de una combinación de estados de polarización que generen modulación sólo de fase

# %% [markdown]
# Script para encontrar la fase vs nivel de gris introducida por la matriz de Jones del modulador. Estoy probando una forma alternativa en la cual no hago uso de la función "arctan" para obtener la fase introducida por la matriz de Jones antes de encontrar el parámetro beta.
# En vez de eso estoy extrayendo el ángulo del valor que se produce cuando el ket es multiplicado por la matriz M.

# %%
from numpy import arctan,arctan2, info

phi = zeros(52)

## Sección que sigue lo usado por I. Moreno, dónde a partir de una formula 
## y las variables X,Y,Z,w del modulador se extrae la fase.

#chi1 = 0#pi/4#0.3490658503988659#-0.43307956358421984#0.2181361052344816
#chi2 = 0#pi/4#0.3490658503988659#0.59291218452902072#0.63376524318875027
#for i in range(0,52):
#    phi[i] = arctan((Y[i]*cos(chi1+chi2)+W[i]*sin(chi1+chi2))/  \
#		            (X[i]*cos(chi1-chi2)+Z[i]*sin(chi1+chi2)))
fig1 = figure()   
for i in range(1,41):
    
    In, Out =brakets[i]
    
    for g in range(52):
        ket2 = Out.H*M[g]*In
        phi[g] = angle(ket2)
        if g>0 and phi[g]-phi[g-1]>pi:
               phi[g] =phi[g]-2*pi
        elif g>0 and phi[g]-phi[g-1] <- pi:
               phi[g] =phi[g]+2*pi
    
             
    phi = phi - phi[0]
    plot(phi,color = 'r')
    image = loadtxt("Imagen{0}_fase".format(i))
    #image = loadtxt('If1-52_fase')#"Im{0}_fase".format(i))
    plot(image[::,1],color = 'b')
    beta = image[::,1]-phi
    plot(beta,color = 'g')
show()

# %%
def measure_best_modulation(x0, Jones_matrix, beta, a, b):
    """ Function for finding a configuration where phase modulation 
    is maximum and intensity variation is a minimum
    
    x0: Are the variables that we will vary s a list that includes 
        the parameters for input and output of the braket.
        
    Jones_matrix: Is the matrix that we obtained by doing the 
                characterization of the SLM.
    
    beta: Is the global phase by gray level that the SLM introduces.
    
    a, b: Are weights used to give more or less priority to a state where 
          flatness of the intensity curve is prioritized or range of phase
          modulation is.
    """

    chi2,phi2,chi1,phi1 = x0
    from numpy import arctan2
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    
    In, Out =intensity([ chi2,   -phi2],     [chi1,phi1])
    
    phi_t = zeros(52)
    I = zeros(52)
    cambio = 0
    for g in range(52):
        ket2 = Out.H*exp(1j*beta[g])*M[g]*In # Beta was negative.
        I[g] = (ket2.H*ket2)[0,0].real
        phi_t[g] = arctan2(ket2.imag,ket2.real)
    #plot(phi_t)
    for g in range(52):
        if g>0 and  phi_t[g] - phi_t[g-1] > pi-0.1:
            phi_t[g:] = phi_t[g:]-2*pi
        if g>0 and  phi_t[g] - phi_t[g-1] < -pi+0.1:
            phi_t[g:] = phi_t[g:]+2*pi
    
    phi_t = phi_t - phi_t[0]
    
    p = (max(I)-min(I))/average(I)
    q = max(phi_t)-min(phi_t)
    plot(phi_t)
    return p**a/q**b 

bnds = ((-pi/1, pi/1), (-pi, pi),(-pi/1, pi/1), (-pi/1, pi/1))
#bnds = ((-pi, pi),(-pi, pi), (-pi/2, pi/2))

from scipy.optimize import fmin_l_bfgs_b
res = fmin_l_bfgs_b(measure_best_modulation,[ pi/8,0,pi/8,0],\
                    fprime=None,approx_grad=1,  args = (M,beta,0,2), pgtol=1e-05,bounds =bnds)

#res = minimize(measure_modulation,[ .5,  0.5,  0.5, 0.5], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res[0]

res
# Out:
# (array([ 1.82110708, -2.36355998, -2.8835876 ,  2.50532286]),
#  0.097587499707954869,
#  {'funcalls': 100,
#   'grad': array([-0.11056309, -0.01316834,  0.09487183, -0.01904316]),
#   'nit': 6,
#   'task': b'ABNORMAL_TERMINATION_IN_LNSRCH',
#   'warnflag': 2})

# %%
chi2,phi2,chi1,phi1 = res[0]
#chi2,phi2,chi1,phi1 = [pi/4,pi/2,0,0]
In, Out =intensity([ chi2, phi2],     [chi1,phi1])
print(In, Out)
phi1 = zeros(52)
phi2 = zeros(52)
phi_t = zeros(52)
I = zeros(52)
for g in range(52):
    #*exp(1j*-beta[g])
    ket2 = Out.H*exp(1j*beta[g])*M[g]*In
    #print(ket2)
    I[g] = (ket2.H*ket2)[0,0].real
    phi_t[g] = arctan2(ket2.imag,ket2.real)
#for g in range(52):
    #print('g',g,'phi_t[g] - phi_t[g-1]',phi_t[g] - phi_t[g-1])
    #print('phi_t[g]',phi_t[g],'phi_t[g-1]', phi_t[g-1])
    
    #if g>1 and  phi_t[g] - phi_t[g-1] > pi:
    #    phi_t[g:] = phi_t[g:]-2*pi
    #if g>1 and  phi_t[g] - phi_t[g-1] < -pi:
    #    phi_t[g:] = phi_t[g:]+2*pi
figure()
phi_t = phi_t - phi_t[0]
plot(phi_t)
figure()
plot(I)
abs(max(phi_t)-min(phi_t))
# Out:
# [[-0.96690092+0.j        ]
#  [ 0.20522342-0.15161123j]] [[-0.24770504+0.j        ]
#  [-0.69009740-0.68000573j]]
# 3.2937139717609765

# %%
phi_t
# Out:
# array([  0.00000000e+00,  -1.14584984e-03,  -2.50206601e-03,
#          8.15770518e-03,   7.90122933e-03,   3.23829592e-03,
#          2.19664683e-02,   6.86300065e-03,   3.06724245e-02,
#          1.27665963e-02,   2.93693526e-03,  -3.70268761e-02,
#         -6.55703494e-02,  -5.89714126e-02,  -9.09730249e-02,
#         -1.08561822e-01,  -1.30081563e-01,  -1.58363399e-01,
#         -1.65197449e-01,  -2.04298339e-01,  -2.26954783e-01,
#         -2.79336235e-01,  -3.39530542e-01,  -3.78196784e-01,
#         -4.02440246e-01,  -4.39199729e-01,  -4.99479463e-01,
#         -5.61286538e-01,  -5.85607466e-01,  -6.74814920e-01,
#         -6.99293136e-01,  -7.20001545e-01,  -8.84576650e-01,
#         -9.62688365e-01,  -1.02706164e+00,  -1.11142437e+00,
#         -1.23168201e+00,  -1.36227690e+00,  -1.46706348e+00,
#         -1.58861909e+00,  -1.72016225e+00,  -1.80905564e+00,
#         -1.96442644e+00,  -2.06244189e+00,  -2.12896171e+00,
#         -2.32849128e+00,  -2.47014271e+00,  -2.56749216e+00,
#         -2.84177094e+00,  -2.97712551e+00,  -3.12856277e+00,
#         -3.26304155e+00])

# %%
plot(phi_t)

# %%
phi_t[-5]-phi_t[-6]
# Out:
# -0.097349451613802707

# %%
deg2rad(20)
# Out:
# 0.3490658503988659

# %%
plot(phi_t[::-1])

# %% [raw]
# La función que esta comentntado debajo hace un barrido dobre muchos estados de entrada y salida hasta llegar a una combinación que sea relativamente buena. Lo comenté porque no es muy bueno.

# %% [raw]
# def get_optimal_state(Jones_matrix):
#     """ Function for finding a configuration where the amplitude
#     is not modulated"""
#     def intensity(bra,ket):
#         In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
#         Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
#         return In, Out
#
#     optimal = {'chi1':0,'chi2':0,'theta1':0,'theta2':0,'value':0 }
#     for chi1 in linspace(0,pi,20):
#         for chi2 in linspace(0,pi,20):
#             for theta1 in linspace(0,pi,10):
#                 for theta2 in linspace(0,pi,10):
#                     I_sim = zeros(52)
#                     for g in range(52):
#                         In,Out = intensity([chi2,theta2],[chi1,theta1])
#                         I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
#                     p = (max(I_sim)-min(I_sim))/average(I_sim)
#                     if 1/p >  optimal['value']:
#                         optimal = {'chi1':chi1,'chi2':chi2,'theta1':theta1,'theta2':theta2,'value':p }
#     return optimal
# optimal = get_optimal_state(M)

# %% [markdown]
# Función que sólo optimiza para que la intensidad

# %%
def measure_flatness(x0,Jones_matrix):
    """ Function for finding a configuration where the amplitude
    is not modulated"""
    chi2,phi2,chi1,phi1 = x0
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    I_sim = zeros(52)
    for g in range(52):
        In,Out = intensity([chi2,phi2],[chi1,phi1])
        I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
    return  (max(I_sim)-min(I_sim))/average(I_sim)

bnds = ((-pi/1, pi/1), (-pi/2, pi/2),(-pi/1, pi/1), (-pi/1, pi/1))
res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res.x
res
# Out:
#     nfev: 419
#   status: 0
#     njev: 58
#      nit: 58
#      jac: array([-0.07629883, -0.01148951,  0.37623983, -0.06199344,  0.        ])
#  success: True
#        x: array([ 0.43129657, -1.56709702, -0.70547068,  1.90329825])
#  message: 'Optimization terminated successfully.'
#      fun: 0.013320555374646709

# %%
I_sim = zeros(52)
for g in range(52):
    In,Out = intensity([chi2,phi2],[chi1,phi1])
    I_sim[g] = (In.H*M[g].H*Out * Out.H*M[g]*In)[0,0].real
figure()
plot(I_sim)
ylim((0,1))
# Out:
# (0, 1)

# %%
from numpy import arctan, info
phi = zeros(52)
#chi1 = -0.43307956358421984#0.2181361052344816
#chi2 = 0.59291218452902072#0.63376524318875027
for i in range(0,52):
    phi[i] = arctan((Y[i]*cos(chi1+chi2)+W[i]*sin(chi1+chi2))/\
		            X[i]*cos(chi1-chi2)+Z[i]*sin(chi1+chi2))
figure()
plot(phi)
max(phi)-min(phi)
# Out:
# 1.3497217106153105

# %%
def measure_modulation(x0,Jones_matrix):
    """ Function for finding a configuration where phase modulation 
    is maximum"""
    chi2,phi2,chi1,phi1 = x0
    
    def intensity(bra,ket):
        In  = matrix([[cos(ket[0])],[sin(ket[0])*exp(ket[1]*1j)]])
        Out = matrix([[cos(bra[0])],[sin(bra[0])*exp(bra[1]*1j)]])
        return In, Out
    
    In, Out =intensity([ chi2,   phi2],     [chi1,phi1])
    
    phi_t = zeros(52)
    I = zeros(52)
    for g in range(52):
        ket2 = Out.H*exp(1j*-beta[g])*M[g]*In
        I[g] = (ket2.H*ket2)[0,0].real
        phi_t[g] = (angle(ket2))
        if g>0 and phi_t[g]-phi_t[g-1]>pi:
           phi_t[g] =phi_t[g]-2*pi
        elif g>0 and phi_t[g]-phi_t[g-1] <- pi:
           phi_t[g] =phi_t[g]+2*pi
    print(max(phi_t)-min(phi_t))
    print(1/(max(phi_t)-min(phi_t)))
    return  1/(max(phi_t)-min(phi_t))

bnds = ((-pi/1, pi/1), (-pi, pi),(-pi/1, pi/1), (-pi/1, pi/1))
#bnds = ((-pi, pi),(-pi, pi), (-pi/2, pi/2))

from scipy.optimize import fmin_l_bfgs_b
res = fmin_l_bfgs_b(measure_modulation,[ .5,  0.5,  0.5, 0.5],fprime=None,approx_grad=1,  args = (M,), pgtol=1e-05,bounds =bnds)

#res = minimize(measure_modulation,[ .5,  0.5,  0.5, 0.5], args = (M,),method = 'SLSQP',bounds =bnds)
#res = minimize(measure_flatness,[ 0,  0,  0, 0], args = (M,),)   
chi2,phi2,chi1,phi1 = res[0]

res
# Out:
# 4.55385037098
# 0.219594391237
# 4.55385037098
# 0.219594391237
# 4.55385035162
# 0.219594392171
# 4.55385038126
# 0.219594390741
# 4.55385040165
# 0.219594389758
# 4.5538503707
# 0.219594391251
# 5.24866327097
# 0.190524700933
# 5.24866327097
# 0.190524700933
# 5.24866324218
# 0.190524701978
# 5.24866327244
# 0.19052470088
# 5.24866329253
# 0.19052470015
# 5.24866326079
# 0.190524701303
# 1.47016512062
# 0.680195704534
# 1.47016512062
# 0.680195704534
# 1.47016519773
# 0.680195668856
# 1.47016511315
# 0.680195707991
# 1.47016514563
# 0.680195692961
# 1.47016516464
# 0.680195684167
# 5.57309127567
# 0.179433630374
# 5.57309127567
# 0.179433630374
# 5.57309124924
# 0.179433631225
# 5.57309127384
# 0.179433630433
# 5.5730912884
# 0.179433629964
# 5.57309126291
# 0.179433630785
# 2.57991588896
# 0.387609535753
# 2.57991588896
# 0.387609535753
# 2.57991609129
# 0.387609505354
# 2.57991590466
# 0.387609533394
# 2.5799159531
# 0.387609526115
# 2.5799160177
# 0.387609516411
# 5.76202730807
# 0.173550027887
# 5.76202730807
# 0.173550027887
# 5.76202728408
# 0.173550028609
# 5.76202730522
# 0.173550027973
# 5.76202731571
# 0.173550027657
# 5.76202729465
# 0.173550028291
# 1.25710128545
# 0.795480850729
# 1.25710128545
# 0.795480850729
# 1.25710133636
# 0.795480818512
# 1.25710128561
# 0.795480850628
# 1.25710130873
# 0.795480835993
# 1.25710131969
# 0.795480829062
# 5.78070151912
# 0.172989384886
# 5.78070151912
# 0.172989384886
# 5.78070149535
# 0.172989385597
# 5.7807015162
# 0.172989384973
# 5.78070152629
# 0.172989384671
# 5.78070150565
# 0.172989385289
# 2.28721550545
# 0.437212845758
# 2.28721550545
# 0.437212845758
# 2.28721563462
# 0.437212821066
# 2.28721551679
# 0.43721284359
# 2.28721555252
# 0.43721283676
# 2.28721558922
# 0.437212829745
# 5.80252594398
# 0.172338738276
# 5.80252594398
# 0.172338738276
# 5.80252592049
# 0.172338738974
# 5.80252594101
# 0.172338738364
# 5.80252595061
# 0.172338738079
# 5.80252593047
# 0.172338738677
# 6.14755742299
# 0.162666231674
# 6.14755742299
# 0.162666231674
# 6.14755740508
# 0.162666232148
# 6.14755742037
# 0.162666231744
# 6.14755742201
# 0.1626662317
# 6.14755741001
# 0.162666232018
# 0.682433435498
# 1.46534438083
# 0.682433435498
# 1.46534438083
# 0.682433458887
# 1.46534433061
# 0.682433436913
# 1.46534437779
# 0.682433419583
# 1.46534441501
# 0.682433441181
# 1.46534436863
# 6.15088662786
# 0.162578187585
# 6.15088662786
# 0.162578187585
# 6.15088660999
# 0.162578188058
# 6.15088662526
# 0.162578187654
# 6.15088662682
# 0.162578187613
# 6.15088661489
# 0.162578187928
# 0.990310360374
# 1.0097844474
# 0.990310360374
# 1.0097844474
# 0.990310389614
# 1.00978441758
# 0.990310360441
# 1.00978444733
# 0.9903103492
# 1.00978445879
# 0.990310371275
# 1.00978443628
# 6.15260831187
# 0.162532693341
# 6.15260831187
# 0.162532693341
# 6.15260829402
# 0.162532693813
# 6.15260830927
# 0.16253269341
# 6.1526083108
# 0.162532693369
# 6.15260829889
# 0.162532693684
# 1.43645665249
# 0.696157449836
# 1.43645665249
# 0.696157449836
# 1.4364567248
# 0.696157414796
# 1.43645665411
# 0.696157449052
# 1.43645666253
# 0.696157444974
# 1.43645669481
# 0.696157429327
# 6.15395757467
# 0.162497057847
# 6.15395757467
# 0.162497057847
# 6.15395755684
# 0.162497058318
# 6.15395757208
# 0.162497057916
# 6.15395757358
# 0.162497057876
# 6.1539575617
# 0.16249705819
# 1.8639000095
# 0.536509466657
# 1.8639000095
# 0.536509466657
# 1.86390008491
# 0.536509444953
# 1.86390001432
# 0.53650946527
# 1.86390003335
# 0.536509459794
# 1.8639000573
# 0.536509452898
# 6.15462688488
# 0.162479386436
# 6.15462688488
# 0.162479386436
# 6.15462686706
# 0.162479386907
# 6.1546268823
# 0.162479386505
# 6.15462688378
# 0.162479386465
# 6.15462687191
# 0.162479386779
# 2.29171066857
# 0.43635525798
# 2.29171066857
# 0.43635525798
# 2.29171086116
# 0.436355221309
# 2.29171068332
# 0.436355255173
# 2.29171071486
# 0.436355249166
# 2.29171078669
# 0.43635523549
# 6.15508700581
# 0.162467240358
# 6.15508700581
# 0.162467240358
# 6.15508698799
# 0.162467240829
# 6.15508700323
# 0.162467240427
# 6.1550870047
# 0.162467240388
# 6.15508699285
# 0.162467240701
# 2.78271595845
# 0.359361147502
# 2.78271595845
# 0.359361147502
# 2.78271616055
# 0.359361121402
# 2.78271597796
# 0.359361144983
# 2.78271601737
# 0.359361139892
# 2.78271608521
# 0.359361131132
# 6.15532409305
# 0.162460982538
# 6.15532409305
# 0.162460982538
# 6.15532407524
# 0.162460983009
# 6.15532409047
# 0.162460982607
# 6.15532409194
# 0.162460982568
# 6.15532408009
# 0.162460982881
# 6.21458876021
# 0.160911693209
# 6.21458876021
# 0.160911693209
# 6.21458874316
# 0.16091169365
# 6.21458875792
# 0.160911693268
# 6.21458875814
# 0.160911693262
# 6.21458874743
# 0.16091169354
# 6.23426590156
# 0.160403809493
# 6.23426590156
# 0.160403809493
# 6.23426588477
# 0.160403809925
# 6.23426589939
# 0.160403809549
# 6.23426589921
# 0.160403809553
# 6.23426588885
# 0.16040380982
# 3.00242506099
# 0.333064099748
# 3.00242506099
# 0.333064099748
# 3.00242616378
# 0.333063977414
# 3.00242515725
# 0.33306408907
# 3.0024253001
# 0.333064073224
# 3.00242573175
# 0.33306402534
# 6.23426590156
# 0.160403809493
# 6.23426590156
# 0.160403809493
# 6.23426588477
# 0.160403809925
# 6.23426589939
# 0.160403809549
# 6.23426589921
# 0.160403809553
# 6.23426588885
# 0.16040380982
# 1.06904131094
# 0.935417546325
# 1.06904131094
# 0.935417546325
# 1.06904129567
# 0.93541755969
# 1.06904131603
# 0.935417541869
# 1.06904131196
# 0.935417545433
# 1.06904130217
# 0.935417554
# 3.0515937239
# 0.327697619827
# 3.0515937239
# 0.327697619827
# 3.05159472748
# 0.327697512057
# 3.05159381902
# 0.327697609612
# 3.05159399604
# 0.327697590603
# 3.05159434735
# 0.327697552877
# 6.23426680127
# 0.160403786344
# 6.23426680127
# 0.160403786344
# 6.23426678447
# 0.160403786776
# 6.23426679909
# 0.1604037864
# 6.23426679891
# 0.160403786404
# 6.23426678855
# 0.160403786671
# 6.23803686034
# 0.160306843706
# 6.23803686034
# 0.160306843706
# 6.23803684358
# 0.160306844136
# 6.23803685818
# 0.160306843761
# 6.23803685793
# 0.160306843768
# 6.23803684763
# 0.160306844032
# 3.08852237084
# 0.323779425864
# 3.08852237084
# 0.323779425864
# 3.08852333595
# 0.323779324689
# 3.08852246795
# 0.323779415684
# 3.08852267298
# 0.32377939419
# 3.08852298023
# 0.32377936198
# 6.23803690399
# 0.160306842584
# 6.23803690399
# 0.160306842584
# 6.23803688723
# 0.160306843014
# 6.23803690184
# 0.160306842639
# 6.23803690158
# 0.160306842646
# 6.23803689128
# 0.16030684291
# 6.23814439181
# 0.160304080379
# 6.23814439181
# 0.160304080379
# 6.23814437505
# 0.16030408081
# 6.23814438966
# 0.160304080434
# 6.2381443894
# 0.160304080441
# 6.2381443791
# 0.160304080705
# 3.12035161607
# 0.320476703603
# 3.12035161607
# 0.320476703603
# 3.12035254748
# 0.320476607942
# 3.12035171465
# 0.320476693478
# 3.12035194239
# 0.320476670088
# 3.12035221264
# 0.320476642332
# 6.23814440108
# 0.160304080141
# 6.23814440108
# 0.160304080141
# 6.23814438432
# 0.160304080571
# 6.23814439892
# 0.160304080196
# 6.23814439866
# 0.160304080203
# 6.23814438837
# 0.160304080467
# 6.23814441034
# 0.160304079903
# 6.23814441034
# 0.160304079903
# 6.23814439359
# 0.160304080333
# 6.23814440819
# 0.160304079958
# 6.23814440793
# 0.160304079965
# 6.23814439764
# 0.160304080229
# 3.13591269694
# 0.318886428496
# 3.13591269694
# 0.318886428496
# 3.13591361172
# 0.318886335472
# 3.13591279614
# 0.318886418407
# 3.13591303449
# 0.31888639417
# 3.13591328701
# 0.318886368492
# 6.23814441034
# 0.160304079903
# 6.23814441034
# 0.160304079903
# 6.23814439359
# 0.160304080333
# 6.23814440819
# 0.160304079958
# 6.23814440793
# 0.160304079965
# 6.23814439764
# 0.160304080229
# 1.67970104264
# 0.595344037192
# 1.67970104264
# 0.595344037192
# 1.67970102934
# 0.595344041906
# 1.67970104729
# 0.595344035543
# 1.67970104891
# 0.595344034968
# 1.67970103953
# 0.595344038293
# 2.54180187017
# 0.393421694954
# 2.54180187017
# 0.393421694954
# 2.54180206522
# 0.393421664765
# 2.54180188821
# 0.393421692162
# 2.54180193173
# 0.393421685425
# 2.54180199312
# 0.393421675925
# 6.23815843742
# 0.160303719444
# 6.23815843742
# 0.160303719444
# 6.23815842066
# 0.160303719875
# 6.23815843527
# 0.160303719499
# 6.23815843501
# 0.160303719506
# 6.23815842472
# 0.160303719771
# 2.64579026102
# 0.377958908812
# 2.64579026102
# 0.377958908812
# 2.64579045942
# 0.377958880469
# 2.64579027985
# 0.377958906121
# 2.64579032261
# 0.377958900014
# 2.64579038602
# 0.377958890956
# 6.23816482259
# 0.160303555363
# 6.23816482259
# 0.160303555363
# 6.23816480583
# 0.160303555793
# 6.23816482044
# 0.160303555418
# 6.23816482018
# 0.160303555425
# 6.23816480989
# 0.160303555689
# 2.71523322537
# 0.368292487973
# 2.71523322537
# 0.368292487973
# 2.71523342605
# 0.368292460754
# 2.71523324463
# 0.368292485361
# 2.7152332861
# 0.368292479736
# 2.71523335154
# 0.36829247086
# 6.23816768701
# 0.160303481755
# 6.23816768701
# 0.160303481755
# 6.23816767025
# 0.160303482186
# 6.23816768485
# 0.160303481811
# 6.23816768459
# 0.160303481817
# 6.2381676743
# 0.160303482082
# 2.77237664695
# 0.360701350265
# 2.77237664695
# 0.360701350265
# 2.77237684949
# 0.360701323914
# 2.77237666649
# 0.360701347724
# 2.77237670644
# 0.360701342526
# 2.77237677396
# 0.360701333741
# 6.23816867215
# 0.16030345644
# 6.23816867215
# 0.16030345644
# 6.23816865539
# 0.160303456871
# 6.23816866999
# 0.160303456495
# 6.23816866973
# 0.160303456502
# 6.23816865944
# 0.160303456766
# 2.8914821848
# 0.345843389684
# 2.8914821848
# 0.345843389684
# 2.89148331823
# 0.345843254116
# 2.89148226627
# 0.345843379939
# 2.89148230435
# 0.345843375385
# 2.89148284316
# 0.345843310939
# 6.23816915665
# 0.160303443989
# 6.23816915665
# 0.160303443989
# 6.2381691399
# 0.16030344442
# 6.2381691545
# 0.160303444045
# 6.23816915424
# 0.160303444051
# 6.23816914395
# 0.160303444316
# 2.98410405597
# 0.335108957745
# 2.98410405597
# 0.335108957745
# 2.98410511276
# 0.33510883907
# 2.98410414546
# 0.335108947696
# 2.98410426566
# 0.335108934198
# 2.98410469371
# 0.335108886129
# 6.23816937544
# 0.160303438367
# 6.23816937544
# 0.160303438367
# 6.23816935868
# 0.160303438798
# 6.23816937329
# 0.160303438423
# 6.23816937303
# 0.160303438429
# 6.23816936273
# 0.160303438694
# 3.04265954961
# 0.328659839754
# 3.04265954961
# 0.328659839754
# 3.04266055328
# 0.32865973134
# 3.04265964334
# 0.328659829629
# 3.04265981182
# 0.328659811431
# 3.04266017064
# 0.328659772671
# 6.238169473
# 0.16030343586
# 6.238169473
# 0.16030343586
# 6.23816945624
# 0.160303436291
# 6.23816947084
# 0.160303435916
# 6.23816947058
# 0.160303435922
# 6.23816946029
# 0.160303436187
# 3.08009496262
# 0.324665314588
# 3.08009496262
# 0.324665314588
# 3.08009593083
# 0.324665212531
# 3.08009505872
# 0.324665304459
# 3.08009525627
# 0.324665283635
# 3.08009557163
# 0.324665250393
# 6.23816951615
# 0.160303434751
# 6.23816951615
# 0.160303434751
# 6.23816949939
# 0.160303435182
# 6.23816951399
# 0.160303434807
# 6.23816951373
# 0.160303434813
# 6.23816950344
# 0.160303435078
# 6.2381695593
# 0.160303433643
# 6.2381695593
# 0.160303433643
# 6.23816954254
# 0.160303434073
# 6.23816955714
# 0.160303433698
# 6.23816955688
# 0.160303433705
# 6.23816954659
# 0.160303433969
# 3.11547570687
# 0.320978269159
# 3.11547570687
# 0.320978269159
# 3.11547664069
# 0.320978172951
# 3.11547580493
# 0.320978259057
# 3.11547602854
# 0.320978236019
# 3.11547630363
# 0.320978207678
# 6.23816957024
# 0.160303433361
# 6.23816957024
# 0.160303433361
# 6.23816955348
# 0.160303433792
# 6.23816956809
# 0.160303433417
# 6.23816956783
# 0.160303433423
# 6.23816955754
# 0.160303433688
# 1.87720897444
# 0.532705742202
# 1.87720897444
# 0.532705742202
# 1.87720907292
# 0.532705714257
# 1.87720898004
# 0.532705740614
# 1.87720899296
# 0.532705736948
# 1.87720903405
# 0.532705725287
# 6.23832908566
# 0.160299334368
# 6.23832908566
# 0.160299334368
# 6.23832906891
# 0.160299334799
# 6.23832908351
# 0.160299334423
# 6.23832908325
# 0.16029933443
# 6.23832907296
# 0.160299334694
# 2.09580661417
# 0.477143259896
# 2.09580661417
# 0.477143259896
# 2.0958067143
# 0.477143237102
# 2.09580662147
# 0.477143258235
# 2.09580663894
# 0.477143254259
# 2.09580667624
# 0.477143245766
# 3.13697259868
# 0.318778685036
# 3.13697259868
# 0.318778685036
# 3.13697351128
# 0.318778592297
# 3.13697269782
# 0.318778674961
# 3.13697293657
# 0.3187786507
# 3.13697318765
# 0.318778625185
# 6.23832908588
# 0.160299334362
# 6.23832908588
# 0.160299334362
# 6.23832906912
# 0.160299334793
# 6.23832908372
# 0.160299334418
# 6.23832908346
# 0.160299334425
# 6.23832907317
# 0.160299334689
# 6.23832908609
# 0.160299334357
# 6.23832908609
# 0.160299334357
# 6.23832906933
# 0.160299334788
# 6.23832908393
# 0.160299334412
# 6.23832908367
# 0.160299334419
# 6.23832907338
# 0.160299334684
# 3.13929147938
# 0.318543214788
# 3.13929147938
# 0.318543214788
# 3.13929238968
# 0.318543122421
# 3.13929157863
# 0.318543204717
# 3.13929181898
# 0.31854318033
# 3.13929206748
# 0.318543155114
# 6.23832908614
# 0.160299334356
# 6.23832908614
# 0.160299334356
# 6.23832906938
# 0.160299334786
# 6.23832908399
# 0.160299334411
# 6.23832908372
# 0.160299334418
# 6.23832907343
# 0.160299334682
# 3.14007888748
# 0.318463336697
# 3.14007888748
# 0.318463336697
# 3.14007979699
# 0.318463244456
# 3.14007898677
# 0.318463326628
# 3.14007922765
# 0.318463302198
# 3.14007947528
# 0.318463277083
# 6.23832908616
# 0.160299334355
# 6.23832908616
# 0.160299334355
# 6.2383290694
# 0.160299334786
# 6.23832908401
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334682
# 3.1405982955
# 0.318410667622
# 3.1405982955
# 0.318410667622
# 3.14059920449
# 0.318410575463
# 3.1405983948
# 0.318410657553
# 3.14059863604
# 0.318410633095
# 3.1405988831
# 0.318410608047
# 6.23832908616
# 0.160299334355
# 6.23832908616
# 0.160299334355
# 6.2383290694
# 0.160299334786
# 6.23832908401
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334682
# 1.25904527802
# 0.79425261145
# 1.25904527802
# 0.79425261145
# 1.25904527401
# 0.79425261398
# 1.25904528531
# 0.794252606848
# 1.25904528191
# 0.794252608997
# 1.25904527313
# 0.794252614536
# 2.56618627007
# 0.389683325666
# 2.56618627007
# 0.389683325666
# 2.56618646513
# 0.389683296046
# 2.56618628912
# 0.389683322773
# 2.56618633533
# 0.389683315756
# 2.5661863944
# 0.389683306787
# 3.1409736581
# 0.318372615899
# 3.1409736581
# 0.318372615899
# 3.14097456656
# 0.318372523817
# 3.14097375741
# 0.318372605833
# 3.14097399885
# 0.31837258136
# 3.14097424546
# 0.318372556364
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908401
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334682
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 3.14128980307
# 0.318340574315
# 3.14128980307
# 0.318340574315
# 3.1412907113
# 0.318340482275
# 3.1412899024
# 0.318340564249
# 3.14129014409
# 0.318340539756
# 3.14129039036
# 0.318340514798
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 3.14139728595
# 0.318329682295
# 3.14139728595
# 0.318329682295
# 3.1413981941
# 0.31832959027
# 3.14139738529
# 0.318329672229
# 3.14139762706
# 0.31832964773
# 3.14139787322
# 0.318329622785
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 3.14146822286
# 0.318322494152
# 3.14146822286
# 0.318322494152
# 3.14146913095
# 0.318322402136
# 3.14146832221
# 0.318322484085
# 3.14146856403
# 0.318322459581
# 3.14146881012
# 0.318322434646
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 3.14153707203
# 0.318315517872
# 3.14153707203
# 0.318315517872
# 3.14153798007
# 0.318315425866
# 3.14153717138
# 0.318315507806
# 3.14153741326
# 0.318315483298
# 3.14153765927
# 0.318315458371
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 3.14157149612
# 0.318312029898
# 3.14157149612
# 0.318312029898
# 3.14157240413
# 0.318311937896
# 3.14157159547
# 0.318312019832
# 3.14157183737
# 0.318311995322
# 3.14157208335
# 0.318311970399
# 6.23832908617
# 0.160299334355
# 6.23832908617
# 0.160299334355
# 6.23832906941
# 0.160299334786
# 6.23832908402
# 0.16029933441
# 6.23832908375
# 0.160299334417
# 6.23832907346
# 0.160299334681
# 6.2383291803
# 0.160299331936
# 6.2383291803
# 0.160299331936
# 6.23832916354
# 0.160299332367
# 6.23832917814
# 0.160299331992
# 6.23832917788
# 0.160299331998
# 6.23832916759
# 0.160299332263
# 3.14158611483
# 0.3183105487
# 3.14158611483
# 0.3183105487
# 3.14158702283
# 0.3183104567
# 3.14158621418
# 0.318310538634
# 3.14158645609
# 0.318310514123
# 3.14158670205
# 0.318310489202
# 6.2383291803
# 0.160299331936
# 6.2383291803
# 0.160299331936
# 6.23832916354
# 0.160299332367
# 6.23832917814
# 0.160299331992
# 6.23832917788
# 0.160299331998
# 6.23832916759
# 0.160299332263
# 1.87628882597
# 0.532966985765
# 1.87628882597
# 0.532966985765
# 1.87628892443
# 0.532966957797
# 1.87628883156
# 0.532966984178
# 1.87628884445
# 0.532966980514
# 1.87628888556
# 0.532966968837
# 3.13190509562
# 0.319294477153
# 3.13190509562
# 0.319294477153
# 3.13190601327
# 0.3192943836
# 3.13190519453
# 0.31929446707
# 3.13190542977
# 0.319294443088
# 3.13190568648
# 0.319294416915
# 6.23832908708
# 0.160299334332
# 6.23832908708
# 0.160299334332
# 6.23832907032
# 0.160299334762
# 6.23832908493
# 0.160299334387
# 6.23832908466
# 0.160299334394
# 6.23832907437
# 0.160299334658
# 6.238329088
# 0.160299334308
# 6.238329088
# 0.160299334308
# 6.23832907124
# 0.160299334739
# 6.23832908585
# 0.160299334363
# 6.23832908558
# 0.16029933437
# 6.23832907529
# 0.160299334634
# 3.1367651351
# 0.318799768848
# 3.1367651351
# 0.318799768848
# 3.13676604792
# 0.318799676075
# 3.13676523424
# 0.318799758772
# 3.13676547284
# 0.318799734522
# 3.13676572415
# 0.318799708981
# 6.23832908823
# 0.160299334302
# 6.23832908823
# 0.160299334302
# 6.23832907147
# 0.160299334733
# 6.23832908608
# 0.160299334357
# 6.23832908581
# 0.160299334364
# 6.23832907552
# 0.160299334629
# 6.23832908846
# 0.160299334296
# 6.23832908846
# 0.160299334296
# 6.2383290717
# 0.160299334727
# 6.23832908631
# 0.160299334351
# 6.23832908604
# 0.160299334358
# 6.23832907575
# 0.160299334623
# 3.13918788721
# 0.31855372661
# 3.13918788721
# 0.31855372661
# 3.13918879761
# 0.318553634226
# 3.13918798645
# 0.318553716539
# 3.13918822672
# 0.318553692158
# 3.13918847534
# 0.318553666928
# 6.23832908852
# 0.160299334295
# 6.23832908852
# 0.160299334295
# 6.23832907176
# 0.160299334725
# 6.23832908636
# 0.16029933435
# 6.2383290861
# 0.160299334357
# 6.23832907581
# 0.160299334621
# 3.14001051959
# 0.318470270645
# 3.14001051959
# 0.318470270645
# 3.14001142917
# 0.318470178392
# 3.14001061887
# 0.318470260575
# 3.1400108597
# 0.318470236149
# 3.14001110741
# 0.318470211025
# 6.23832908854
# 0.160299334294
# 6.23832908854
# 0.160299334294
# 6.23832907178
# 0.160299334725
# 6.23832908639
# 0.160299334349
# 6.23832908613
# 0.160299334356
# 6.23832907583
# 0.16029933462
# 6.23832908857
# 0.160299334293
# 6.23832908857
# 0.160299334293
# 6.23832907181
# 0.160299334724
# 6.23832908641
# 0.160299334349
# 6.23832908615
# 0.160299334355
# 6.23832907586
# 0.16029933462
# 3.14080842054
# 0.318389365445
# 3.14080842054
# 0.318389365445
# 3.14080932933
# 0.31838927332
# 3.14080851986
# 0.318389355377
# 3.14080876124
# 0.318389330907
# 3.14080900807
# 0.318389305886
# 6.23832908857
# 0.160299334293
# 6.23832908857
# 0.160299334293
# 6.23832907182
# 0.160299334724
# 6.23832908642
# 0.160299334349
# 6.23832908616
# 0.160299334355
# 6.23832907587
# 0.16029933462
# 6.23832908903
# 0.160299334282
# 6.23832908903
# 0.160299334282
# 6.23832907227
# 0.160299334712
# 6.23832908687
# 0.160299334337
# 6.23832908661
# 0.160299334344
# 6.23832907632
# 0.160299334608
# 3.14120716132
# 0.31834894951
# 3.14120716132
# 0.31834894951
# 3.14120806971
# 0.318348857449
# 3.14120726066
# 0.318348939443
# 3.14120750231
# 0.318348914952
# 3.1412077487
# 0.318348889982
# 6.23832908903
# 0.160299334281
# 6.23832908903
# 0.160299334281
# 6.23832907227
# 0.160299334712
# 6.23832908687
# 0.160299334337
# 6.23832908661
# 0.160299334344
# 6.23832907632
# 0.160299334608
# 6.23832908903
# 0.160299334281
# 6.23832908903
# 0.160299334281
# 6.23832907227
# 0.160299334712
# 6.23832908688
# 0.160299334337
# 6.23832908661
# 0.160299334344
# 6.23832907632
# 0.160299334608
# 3.14140648221
# 0.318328750406
# 3.14140648221
# 0.318328750406
# 3.1414073904
# 0.318328658377
# 3.14140658156
# 0.318328740339
# 3.14140682335
# 0.318328715838
# 3.14140706951
# 0.318328690893
# 6.23832908903
# 0.160299334281
# 6.23832908903
# 0.160299334281
# 6.23832907227
# 0.160299334712
# 6.23832908688
# 0.160299334337
# 6.23832908661
# 0.160299334344
# 6.23832907632
# 0.160299334608
# (array([ 0.12245541,  0.56477646,  0.77754208,  0.34971996]),
#  0.16029933428143708,
#  {'funcalls': 111,
#   'grad': array([ 0.04306071,  0.00553413,  0.0062093 ,  0.03265151]),
#   'nit': 7,
#   'task': b'ABNORMAL_TERMINATION_IN_LNSRCH',
#   'warnflag': 2})
